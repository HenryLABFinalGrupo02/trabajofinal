# %% [markdown]
# # Review EDA

# %%
# Conectamos con el google drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -a
# Out:
# .  ..  .config	drive  sample_data

# %%
# Instalamos las dependencias de nuestro entorno de trabajo 
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://apache.osuosl.org/spark/spark-3.1.3/spark-3.1.3-bin-hadoop2.7.tgz
# !tar xf spark-3.1.3-bin-hadoop2.7.tgz
# !pip install -q findspark
! pip install koalas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting koalas
#   Downloading koalas-1.8.2-py3-none-any.whl (390 kB)
#      |████████████████████████████████| 390 kB 7.2 MB/s
# Requirement already satisfied: pyarrow>=0.10 in /usr/local/lib/python3.7/dist-packages (from koalas) (6.0.1)
# Requirement already satisfied: pandas>=0.23.2 in /usr/local/lib/python3.7/dist-packages (from koalas) (1.3.5)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.7/dist-packages (from koalas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.2->koalas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.2->koalas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.2->koalas) (1.15.0)
# Installing collected packages: koalas
# Successfully installed koalas-1.8.2

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.3-bin-hadoop2.7"

# %%
from pathlib import Path
import databricks.koalas as ks
import findspark
from datetime import datetime
findspark.init()

from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
def import_convert(path:Path, format:str): 
    data = spark.read.load(path, format=format)
    data = data.to_koalas()
    return data

# %%
k_review = import_convert("/content/drive/MyDrive/HENRY_TRABAJO_GRUPAL/Repository/Data/review.json", "json")

# %% [markdown]
# ## Now we start gathering some basic info about the 'review' dataset

# %% [markdown]
# ## --------- GENERAL INFO ---------

# %%
k_review.columns
# Out:
# Index(['business_id', 'cool', 'date', 'funny', 'review_id', 'stars', 'text',
#        'useful', 'user_id'],
#       dtype='object')

# %%
k_review.head()
# Out:
#               business_id  cool                 date  funny               review_id  stars                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               text  useful                 user_id
# 0  XQfwVwDr-v0ZS3_CbbE5Xw     0  2018-07-07 22:09:11      0  KU_O5udG6zpxOg-VcAEodg    3.0                                                                                                                                                                                                                                                                                                                                If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to it's other locations in NJ and never had a bad experience. \n\nThe food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.       0  mh_-eMZ6K5RLWhZyISBhwA
# 1  7ATYjTIgM3jUlt4UM3IypQ     1  2012-01-03 15:28:18      0  BiTunyQ73aT9WBnpR9DZGw    5.0  I've taken a lot of spin classes over the years, and nothing compares to the classes at Body Cycle. From the nice, clean space and amazing bikes, to the welcoming and motivating instructors, every class is a top notch work out.\n\nFor anyone who struggles to fit workouts in, the online scheduling system makes it easy to plan ahead (and there's no need to line up way in advanced like many gyms make you do).\n\nThere is no way I can write this review without giving Russell, the owner of Body Cycle, a shout out. Russell's passion for fitness and cycling is so evident, as is his desire for all of his clients to succeed. He is always dropping in to classes to check in/provide encouragement, and is open to ideas and recommendations from anyone. Russell always wears a smile on his face, even when he's kicking your butt in class!       1  OyoGAe7OKpv6SyGZT5g77Q
# 2  YjUWPpI6HXG530lwP-fb2A     0  2014-02-05 20:30:30      0  saUsX_uimxRlCVr67Z4Jig    3.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Family diner. Had the buffet. Eclectic assortment: a large chicken leg, fried jalapeño, tamale, two rolled grape leaves, fresh melon. All good. Lots of Mexican choices there. Also has a menu with breakfast served all day long. Friendly, attentive staff. Good place for a casual relaxed meal with no expectations. Next to the Clarion Hotel.       0  8g_iMtfSiwikVnbP2etR0A
# 3  kxX2SOes4o-D3ZQBkiMRfA     1  2015-01-04 00:01:03      0  AqPFMleE6RsU23_auESxiA    5.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Wow!  Yummy, different,  delicious.   Our favorite is the lamb curry and korma.  With 10 different kinds of naan!!!  Don't let the outside deter you (because we almost changed our minds)...go in and try something new!   You'll be glad you did!       1  _7bHUi9Uuf5__HHc_Q8guQ
# 4  e4Vwtrqf-wpJfwesgvdgxQ     1  2017-01-14 20:54:15      0  Sx8TMOWLNuJBWer-0pcmoA    4.0                                                                                                                                                                                                                                                                                                             Cute interior and owner (?) gave us tour of upcoming patio/rooftop area which will be great on beautiful days like today. Cheese curds were very good and very filling. Really like that sandwiches come w salad, esp after eating too many curds! Had the onion, gruyere, tomato sandwich. Wasn't too much cheese which I liked. Needed something else...pepper jelly maybe. Would like to see more menu options added such as salads w fun cheeses. Lots of beer and wine as well as limited cocktails. Next time I will try one of the draft wines.       1  bcjbaE6dDog4jkNY91ncLQ

# %%
k_review.shape
# Out:
# (6990280, 9)

# %%
# Count of rows duplicated

k_review.duplicated().sum()
# Out:
# 0

# %%
k_review.info()
# Out:
# <class 'databricks.koalas.frame.DataFrame'>
# Int64Index: 6990280 entries, 0 to 6990279
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   business_id  6990280 non-null  object
#  1   cool         6990280 non-null  int64
#  2   date         6990280 non-null  object
#  3   funny        6990280 non-null  int64
#  4   review_id    6990280 non-null  object
#  5   stars        6990280 non-null  float64
#  6   text         6990280 non-null  object
#  7   useful       6990280 non-null  int64
#  8   user_id      6990280 non-null  object
# dtypes: float64(1), int64(3), object(5)

# %%
k_review.describe()
# Out:
#                cool         funny         stars        useful
# count  6.990280e+06  6.990280e+06  6.990280e+06  6.990280e+06
# mean   4.986175e-01  3.265596e-01  3.748584e+00  1.184609e+00
# std    2.172460e+00  1.688729e+00  1.478705e+00  3.253767e+00
# min   -1.000000e+00 -1.000000e+00  1.000000e+00 -1.000000e+00
# 25%    0.000000e+00  0.000000e+00  3.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  4.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  5.000000e+00  1.000000e+00
# max    4.040000e+02  7.920000e+02  5.000000e+00  1.182000e+03

# %%
k_review.nunique().plot(kind = 'bar', title='Cantidad de Valores únicos')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fae09f26-0e7d-4588-b5ec-8185a3bb3b59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fae09f26-0e7d-4588-b5ec-8185a3bb3b59")) {                    Plotly.newPlot(                        "fae09f26-0e7d-4588-b5ec-8185a3bb3b59",                        [{"alignmentgroup":"True","hovertemplate":"variable=0<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["business_id","cool","date","funny","review_id","stars","text","useful","user_id"],"xaxis":"x","y":[150346,210,6885665,201,6990280,5,6974127,259,1987929],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{ ...

# %%
# Count of null per column
k_review.isnull().sum()
# Out:
# business_id    0
# cool           0
# date           0
# funny          0
# review_id      0
# stars          0
# text           0
# useful         0
# user_id        0
# dtype: int64

# %%
# Count of null per column
k_review.isna().sum()
# Out:
# business_id    0
# cool           0
# date           0
# funny          0
# review_id      0
# stars          0
# text           0
# useful         0
# user_id        0
# dtype: int64

# %%
k_review.max()
# Out:
# cool       404.0
# funny      792.0
# stars        5.0
# useful    1182.0
# dtype: float64

# %%
k_review.min()
# Out:
# cool     -1.0
# funny    -1.0
# stars     1.0
# useful   -1.0
# dtype: float64

# %%
k_review.mean()
# Out:
# cool      0.498618
# funny     0.326560
# stars     3.748584
# useful    1.184609
# dtype: float64

# %%
k_review.std()
# Out:
# cool      2.172460
# funny     1.688729
# stars     1.478705
# useful    3.253767
# dtype: float64

# %% [markdown]
# ### Now we start a per column analysis. For this, we will define some useful functions.

# %%
def is_empty(value):
  '''
  Determine whether a value is an empty string or not
  '''
  stripped = value.strip()
  if stripped == '':
    return 1
  else:
    return 0

# %% [markdown]
# ## --------- COLUMN: review_id ---------
#
# // string, 22 characters, review's id
#
# "review_id": "zdSx_SD6obEhz9VrW9uAWA"

# %%
# Total different review_id's

print(f"Number of different id's:{len(k_review.review_id.unique())}\nTotal rows: {k_review.shape[0]}")
# Out:
# Number of different id's:6990280
# Total rows: 6990280

# %% [markdown]
# Now we check if all id's are in fact 22 characters strings

# %%
k_review['chars_in_id'] = k_review.review_id.apply(lambda id: len(id))
# Out:
# /content/spark-3.1.3-bin-hadoop2.7/python/pyspark/sql/pandas/functions.py:392: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   "in the future releases. See SPARK-28264 for more details.", UserWarning)

# %%
k_review.chars_in_id.value_counts()
# Out:
# 22    6990280
# Name: chars_in_id, dtype: int64

# %% [markdown]
# All review_id's contain 22 characters. We can drop the created column.

# %%
k_review = k_review.drop('chars_in_id', axis=1)
k_review.columns
# Out:
# Index(['business_id', 'cool', 'date', 'funny', 'review_id', 'stars', 'text',
#        'useful', 'user_id'],
#       dtype='object')

# %% [markdown]
# Now we check if after dropping the review_id column there are still no duplicates

# %%
review_noid = k_review.drop('review_id', axis=1)
review_noid.columns
# Out:
# Index(['business_id', 'cool', 'date', 'funny', 'stars', 'text', 'useful',
#        'user_id'],
#       dtype='object')

# %%
review_noid.duplicated().sum()
# Out:
# 7

# %% [markdown]
# There are 7 duplicated registers if we ignore their id's

# %% [markdown]
# ## --------- COLUMN: user_id ---------
#
# // string, 22 characters unique user id, refiers to user in user.json
#
# "user_id": "Ha3iJu77CxlrFm-vQRs_8g"

# %%
# Amount of users making reviews

len(k_review.user_id.unique())
# Out:
# 1987929

# %% [markdown]
# Now we will check if all user_id's are 22 char strings

# %%
k_review['chars_in_userid'] = k_review.user_id.apply(lambda id: len(id))
# Out:
# /content/spark-3.1.3-bin-hadoop2.7/python/pyspark/sql/pandas/functions.py:392: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   "in the future releases. See SPARK-28264 for more details.", UserWarning)

# %%
k_review.chars_in_userid.value_counts()
# Out:
# 22    6990280
# Name: chars_in_userid, dtype: int64

# %% [markdown]
# All user_id's contain 22 characters. We can drop the created column.

# %%
k_review = k_review.drop('chars_in_userid', axis=1)
k_review.columns
# Out:
# Index(['business_id', 'cool', 'date', 'funny', 'review_id', 'stars', 'text',
#        'useful', 'user_id'],
#       dtype='object')

# %%
# Average amount of reviews per user

k_review.user_id.value_counts().mean()
# Out:
# 3.51636300894046

# %%
# Standard deviation in the amount of reviews posted per user

k_review.user_id.value_counts().std()
# Out:
# 12.770877900860583

# %%
# Top users by amount of reviews posted

k_review.user_id.value_counts().head(15)
# Out:
# _BcWyKQL16ndpBdggh2kNA    3048
# Xw7ZjaGfr0WNVt6s_5KZfA    1840
# 0Igx-a1wAstiBDerGxXk2A    1747
# -G7Zkl1wIWBBmD0KRy_sCw    1682
# ET8n-r7glWYqZhuR6GcdNw    1653
# bYENop4BuQepBjM1-BI3fA    1578
# 1HM81n6n4iPIFU5d2Lokhw    1554
# fr1Hz2acAb3OaL3l6DyKNg    1447
# wXdbkFZsfDR7utJvbWElyA    1396
# Um5bfs5DH6eizgjH3xZsvg    1391
# qjfMBIZpQT9DDtw_BWCopQ    1324
# VL12EhEdT4OWqGq0nIqkzw    1308
# bJ5FtCtZX3ZZacz2_2PJjA    1298
# pou3BbKsIozfH50rxmnMew    1247
# ouODopBKF3AqfCkuQEnrDg    1129
# Name: user_id, dtype: int64

# %%
k_review.user_id.value_counts().head(50)
# Out:
# _BcWyKQL16ndpBdggh2kNA    3048
# Xw7ZjaGfr0WNVt6s_5KZfA    1840
# 0Igx-a1wAstiBDerGxXk2A    1747
# -G7Zkl1wIWBBmD0KRy_sCw    1682
# ET8n-r7glWYqZhuR6GcdNw    1653
# bYENop4BuQepBjM1-BI3fA    1578
# 1HM81n6n4iPIFU5d2Lokhw    1554
# fr1Hz2acAb3OaL3l6DyKNg    1447
# wXdbkFZsfDR7utJvbWElyA    1396
# Um5bfs5DH6eizgjH3xZsvg    1391
# qjfMBIZpQT9DDtw_BWCopQ    1324
# VL12EhEdT4OWqGq0nIqkzw    1308
# bJ5FtCtZX3ZZacz2_2PJjA    1298
# pou3BbKsIozfH50rxmnMew    1247
# ouODopBKF3AqfCkuQEnrDg    1129
# B-s-8VUnuBjGTP3d01jsyw    1087
# -kLVfaJytOJY2-QdQoCcNQ    1076
# vHc-UrI9yfL_pnnc6nJtyQ    1071
# CfX4sTIFFNaRchNswqhVfg    1047
# AHRrG3T1gJpHvtpZ-K0G_g    1041
# I2XpWCHAom1JRyHXZQrnfg    1023
# ppsm8EDKjA1fp1yTCP3RrQ     978
# AaJ9d4OrFmgc4S_U2QiSZg     964
# zYFGMy1_thjMnvQLX6JNBw     954
# PnwOegp7RXfMeNAyO9fQhQ     947
# 2iS1vg5TYpV_iEiNC8osTg     938
# XzpJ4uHkxARCFQiZ9bffyg     927
# eTvp_hYnsrI5-ow_sQ31_g     922
# lYQk0R6sPfo3WeX-l_5BuA     917
# vffKQc_WQMYFGY4JS5VAOw     900
# 6s-g2vFu12OemhiK3FJuOQ     888
# lAW03ccfMEuRZiDqvVgc0w     866
# 0YI3p9o-ntRgRaPWpfa22Q     863
# GcdYgbaF75vj7RO6EZhPOQ     860
# IKbjLnfBQtEyVzEu8CuOLg     844
# vYMvOTL31e0KbTo9Hd0tjg     834
# r3QexFIhBXBT99canAgVEg     830
# WwulXySQN8t2hwqH_yWurA     829
# h7p-GuaHFGsiKCF4g6Bjqg     829
# OIDpKC2p61qVO_spPqw1qA     823
# 6ObFF8-uKnOAlXuSH4TlyQ     820
# iPkdNziqnhNukjnmsrSzmg     790
# E4BsVQnG5zetbwv2x8QIWg     780
# kkPgJv6KBFN15caG7NYYlg     773
# vmUqcqMjlWoBM6qfmUXgyQ     772
# FlXBpK_YZxLo27jcMdII1w     770
# zUk_Ww2q1At1QSyRbUjIGQ     767
# sh3V6hnNMLVV9YwFA9QNaw     764
# A9cXP_K95FRor1qxuUEu2g     758
# lMY8NBPyzlPbbu-KBYfD9A     744
# Name: user_id, dtype: int64

# %%
k_review.user_id.value_counts().head(25).plot(kind = 'bar', title='Cantidad de Valores únicos')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ff785e0c-ebb9-447a-89f0-dbfcca412769" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff785e0c-ebb9-447a-89f0-dbfcca412769")) {                    Plotly.newPlot(                        "ff785e0c-ebb9-447a-89f0-dbfcca412769",                        [{"alignmentgroup":"True","hovertemplate":"variable=user_id<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"user_id","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"user_id","offsetgroup":"user_id","orientation":"v","showlegend":true,"textposition":"auto","x":["_BcWyKQL16ndpBdggh2kNA","Xw7ZjaGfr0WNVt6s_5KZfA","0Igx-a1wAstiBDerGxXk2A","-G7Zkl1wIWBBmD0KRy_sCw","ET8n-r7glWYqZhuR6GcdNw","bYENop4BuQepBjM1-BI3fA","1HM81n6n4iPIFU5d2Lokhw","fr1Hz2acAb3OaL3l6DyKNg","wXdbkFZsfDR7utJvbWElyA","Um5bfs5DH6eizgjH3xZsvg","qjfMBIZpQT9DDtw_BWCopQ","VL12EhEdT4OWqGq0nIqkzw","bJ5FtCtZX3ZZacz2_2PJjA","pou3BbKsIozfH50rxmnMew","ouODopBKF3AqfCkuQEnrDg"],"xaxis":"x","y":[3048,1840,1747,1682,1653,1578,1554,1447,1396,1391,1324,1308,1298,1247,1129],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666 ...

# %%
# Statistics from user with the most posts

k_review[k_review.user_id == '_BcWyKQL16ndpBdggh2kNA'].describe()
# Out:
#               cool        funny        stars       useful
# count  3048.000000  3048.000000  3048.000000  3048.000000
# mean      2.090879     1.097113     3.637795     3.623031
# std       2.214004     1.554317     0.913762     3.383771
# min       0.000000     0.000000     1.000000     0.000000
# 25%       1.000000     0.000000     3.000000     1.000000
# 50%       2.000000     1.000000     4.000000     3.000000
# 75%       3.000000     2.000000     4.000000     5.000000
# max      25.000000    17.000000     5.000000    54.000000

# %%
# Amount of reviews written by most popular user (the one with the most fans)

len(k_review[k_review.user_id == '37cpUoM8hlkSQfReIEBd-Q'])
# Out:
# 59

# %%
# Statistics from most popular user

k_review[k_review.user_id == '37cpUoM8hlkSQfReIEBd-Q'].describe()
# Out:
#             cool      funny      stars     useful
# count  59.000000  59.000000  59.000000  59.000000
# mean    2.864407   2.576271   4.220339   5.559322
# std     1.804760   1.621019   0.810870   3.415337
# min     0.000000   1.000000   2.000000   1.000000
# 25%     1.000000   1.000000   4.000000   3.000000
# 50%     3.000000   2.000000   4.000000   5.000000
# 75%     4.000000   4.000000   5.000000   7.000000
# max     9.000000   9.000000   5.000000  17.000000

# %% [markdown]
# #### ID VALIDATION
#
# Now we will check whether the user_id's reference a register in the 'user' dataset or not. We start by importing the 'user' table and checking if all of it's user_id's have 22 chars.

# %%
user = spark.read.load("/content/drive/MyDrive/HENRY_TRABAJO_GRUPAL/Repository/Data/user.json", format="json")
k_user = user.to_koalas()

# %%
k_user['chars_in_user_id'] = k_user.user_id.apply(lambda id: len(id))
# Out:
# /content/spark-3.1.3-bin-hadoop2.7/python/pyspark/sql/pandas/functions.py:392: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   "in the future releases. See SPARK-28264 for more details.", UserWarning)

# %%
k_user.chars_in_user_id.value_counts()
# Out:
# 22    1987897
# Name: chars_in_user_id, dtype: int64

# %%
k_user = k_user.drop('chars_in_user_id', axis=1)

# %% [markdown]
#  We can see below that there are more unique id's in 'review' than in 'user', so we proceed to check which user_id's from 'review' are not in 'user'.

# %%
rev_usids = k_review.user_id.unique().to_list()

# %%
type(rev_usids), len(rev_usids)
# Out:
# (list, 1987929)

# %%
usr_usids = k_user.user_id.unique().to_list()

# %%
type(usr_usids), len(usr_usids)
# Out:
# (list, 1987897)

# %%
no_review_users = []
for x in usr_usids:
    try:
        rev_usids.remove(x)
    except:
        no_review_users.append(x)

# %%
not_found_users = rev_usids
len(not_found_users)
# Out:
# 32

# %%
len(no_review_users)
# Out:
# 0

# %%
with open("user_not_found.txt", "w") as output:
    output.write(str(not_found_users))

# %% [markdown]
# ## --------- COLUMN: business_id ---------
#
# // string, 22 characters business id, refers to business in business.json
#
# "business_id": "tnhfDv5Il8EaGSXZGiuQGg"

# %%
# Amount of businesses being reviewed

len(k_review.business_id.unique())
# Out:
# 150346

# %% [markdown]
# Now we will check if all business_id's are 22 char strings

# %%
# Most reviewed businesses

k_review.business_id.value_counts().head(15)
# Out:
# _ab50qdWOk0DdB6XOrBitw    7673
# ac1AeYqs8Z4_e2X5M3if2A    7516
# GXFMD0Z4jEVZBCsbPf4CTQ    6160
# ytynqOUb3hjKeJfRj5Tshw    5778
# oBNrLz4EDhiscSlbOl8uAw    5264
# iSRTaT9WngzB8JJ2YKJUig    5254
# VQcCL9PiNL_wkGf-uF3fjg    5146
# _C7QiQQc47AOEv4PE3Kong    4969
# GBTPC53ZrG1ZBY3DT8Mbcw    4661
# 6a4gLLFSgr-Q6CZXDLzBGQ    4480
# PP3BBaVxZLcJU54uP_wL6Q    4293
# 1b5mnK8bMnnju_cvU65GqQ    4247
# I_3LMZ_1m2mzR0oLIOePIg    4093
# VaO-VW3e1kARkU9bP1E7Fw    4034
# qb28j-FNX1_6xm7u372TZA    3971
# Name: business_id, dtype: int64

# %%
business = spark.read.load("/content/drive/MyDrive/HENRY_TRABAJO_GRUPAL/Repository/Data/business.json", format="json")
k_business = business.to_koalas()

# %%
# Businesses with the most reviews (by id)

ks.sql("select b.business_id, first(b.name) Business, count(r.business_id) Reviews from {k_business} b join {k_review} r on r.business_id==b.business_id group by b.business_id order by reviews desc limit 15")
# Out:
#                business_id                            Business  Reviews
# 0   _ab50qdWOk0DdB6XOrBitw                   Acme Oyster House     7673
# 1   ac1AeYqs8Z4_e2X5M3if2A                        Oceana Grill     7516
# 2   GXFMD0Z4jEVZBCsbPf4CTQ  Hattie B’s Hot Chicken - Nashville     6160
# 3   ytynqOUb3hjKeJfRj5Tshw             Reading Terminal Market     5778
# 4   oBNrLz4EDhiscSlbOl8uAw          Ruby Slipper - New Orleans     5264
# 5   iSRTaT9WngzB8JJ2YKJUig                 Mother's Restaurant     5254
# 6   VQcCL9PiNL_wkGf-uF3fjg                         Royal House     5146
# 7   _C7QiQQc47AOEv4PE3Kong                  Commander's Palace     4969
# 8   GBTPC53ZrG1ZBY3DT8Mbcw                                Luke     4661
# 9   6a4gLLFSgr-Q6CZXDLzBGQ                              Cochon     4480
# 10  PP3BBaVxZLcJU54uP_wL6Q                Pat's King of Steaks     4293
# 11  1b5mnK8bMnnju_cvU65GqQ                 Biscuit Love: Gulch     4247
# 12  I_3LMZ_1m2mzR0oLIOePIg                  Pappy's Smokehouse     4093
# 13  VaO-VW3e1kARkU9bP1E7Fw     Felix's Restaurant & Oyster Bar     4034
# 14  qb28j-FNX1_6xm7u372TZA                          Gumbo Shop     3971

# %%
k_review[k_review.business_id == '_ab50qdWOk0DdB6XOrBitw'].stars.mean()
# Out:
# 4.124983709109865

# %%
# Businesses with the most reviews (by brand)

ks.sql("select b.name, count(r.business_id) reviews from {k_business} b join {k_review} r on r.business_id==b.business_id group by b.name order by reviews desc limit 15")
# Out:
#                       name  reviews
# 0                Starbucks    21575
# 1               McDonald's    18210
# 2                  Dunkin'    10312
# 3   Chipotle Mexican Grill     9763
# 4              First Watch     9317
# 5                Taco Bell     8636
# 6        Acme Oyster House     8491
# 7              Chick-fil-A     8378
# 8             Panera Bread     7565
# 9             Oceana Grill     7516
# 10      Buffalo Wild Wings     7347
# 11                 Chili's     6565
# 12          Domino's Pizza     6539
# 13          Steak ’n Shake     6455
# 14                    IHOP     6443

# %%
k_business.columns
# Out:
# Index(['address', 'attributes', 'business_id', 'categories', 'city', 'hours',
#        'is_open', 'latitude', 'longitude', 'name', 'postal_code',
#        'review_count', 'stars', 'state'],
#       dtype='object')

# %%
stars_mean = k_review.stars.mean()

# %%
stars_mean
# Out:
# 3.74858374771826

# %%
ks.sql("select b.name, avg(r.stars) stars_avg, count(r.business_id) reviews from {k_business} b join {k_review} r on r.business_id==b.business_id group by b.name having reviews>50 order by stars_avg desc limit 15")
# Out:
#                                                           name  stars_avg  reviews
# 0                                              Sugar Bar Salon        5.0       55
# 1                                         ByCherry Photography        5.0       73
# 2                                     Truong & Company Jeweler        5.0       61
# 3                             Matt Glynn - Schumacher Mortgage        5.0       60
# 4                                         Waxing by Cody Marie        5.0       53
# 5                                       Jeramie Lu Photography        5.0       77
# 6                                        Delacruz Chiropractic        5.0       67
# 7                                              Gators Parasail        5.0       66
# 8                                    Twisted Twig Fine Florals        5.0       74
# 9                                      Stephen The Spectacular        5.0       53
# 10                                     Walls Jewelry Repairing        5.0      114
# 11  Jack & Melody Cote - Chase International, Reno Real Estate        5.0       69
# 12                                               Drink & Learn        5.0       90
# 13                             It's Sunny in Boise Photography        5.0       51
# 14                                 Guldner's Collision Service        5.0       57

# %% [markdown]
# • compliments (useful+funny+cool) by business

# %%
k_business.shape
# Out:
# (150346, 14)

# %%
len(k_business.name.unique())
# Out:
# 114117

# %%
starbucks_count = 0
for name in k_business.name.to_numpy():
  if name.lower() == 'starbucks':
    starbucks_count += 1
print(starbucks_count)
# Out:
# 724

# %%
mcdonalds_count = 0
for name in k_business.name.to_numpy():
  if name.lower() == "mcdonald's":
    mcdonalds_count += 1
print(mcdonalds_count)
# Out:
# 703

# %% [markdown]
# #### ID VALIDATION
#
# Now we will check whether the business_id's reference a register in the business dataset or not. As we have already imported the business dataset, we procceed to check if all of it's business_id's have 22 chars.

# %%
k_business['chars_in_business_id'] = k_business.business_id.apply(lambda id: len(id))
# Out:
# /content/spark-3.1.3-bin-hadoop2.7/python/pyspark/sql/pandas/functions.py:392: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   "in the future releases. See SPARK-28264 for more details.", UserWarning)

# %%
k_business['chars_in_business_id'].value_counts()
# Out:
# 22    150346
# Name: chars_in_business_id, dtype: int64

# %%
k_business = k_business.drop('chars_in_business_id', axis=1)

# %% [markdown]
# Althought there is the same amount of 'business_id' values in 'review' as in 'business' we will check if there is correspondence between these columns.

# %%
rev_buids = k_review.business_id.unique().to_list()
bus_buids = k_business.business_id.unique().to_list()

# %%
def no_review_businesses(ids_review, ids_in_dim):
  no_review_businesses = []
  for x in ids_in_dim:
    try:
      ids_review.remove(x)
    except:
      no_review_businesses.append(x)

  return ids_review, no_review_businesses

# %%
rev_buids, no_review_businesses = no_review_businesses(rev_buids, no_review_businesses)

# %%
len(rev_buids)
# Out:
# 0

# %% [markdown]
# From the output obove, we can see that all business_id values correspond.

# %% [markdown]
# ## --------- COLUMN: date ---------
#
# // string, fecha formato YYYY-MM-DD
#
# "date": "2016-03-09"

# %%
k_review['datetime'] = k_review.date.astype(datetime)

# %%
k_review.head()
# Out:
#               business_id  cool                 date  funny               review_id  stars                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               text  useful                 user_id            datetime
# 0  XQfwVwDr-v0ZS3_CbbE5Xw     0  2018-07-07 22:09:11      0  KU_O5udG6zpxOg-VcAEodg    3.0                                                                                                                                                                                                                                                                                                                                If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to it's other locations in NJ and never had a bad experience. \n\nThe food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.       0  mh_-eMZ6K5RLWhZyISBhwA 2018-07-07 22:09:11
# 1  7ATYjTIgM3jUlt4UM3IypQ     1  2012-01-03 15:28:18      0  BiTunyQ73aT9WBnpR9DZGw    5.0  I've taken a lot of spin classes over the years, and nothing compares to the classes at Body Cycle. From the nice, clean space and amazing bikes, to the welcoming and motivating instructors, every class is a top notch work out.\n\nFor anyone who struggles to fit workouts in, the online scheduling system makes it easy to plan ahead (and there's no need to line up way in advanced like many gyms make you do).\n\nThere is no way I can write this review without giving Russell, the owner of Body Cycle, a shout out. Russell's passion for fitness and cycling is so evident, as is his desire for all of his clients to succeed. He is always dropping in to classes to check in/provide encouragement, and is open to ideas and recommendations from anyone. Russell always wears a smile on his face, even when he's kicking your butt in class!       1  OyoGAe7OKpv6SyGZT5g77Q 2012-01-03 15:28:18
# 2  YjUWPpI6HXG530lwP-fb2A     0  2014-02-05 20:30:30      0  saUsX_uimxRlCVr67Z4Jig    3.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Family diner. Had the buffet. Eclectic assortment: a large chicken leg, fried jalapeño, tamale, two rolled grape leaves, fresh melon. All good. Lots of Mexican choices there. Also has a menu with breakfast served all day long. Friendly, attentive staff. Good place for a casual relaxed meal with no expectations. Next to the Clarion Hotel.       0  8g_iMtfSiwikVnbP2etR0A 2014-02-05 20:30:30
# 3  kxX2SOes4o-D3ZQBkiMRfA     1  2015-01-04 00:01:03      0  AqPFMleE6RsU23_auESxiA    5.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Wow!  Yummy, different,  delicious.   Our favorite is the lamb curry and korma.  With 10 different kinds of naan!!!  Don't let the outside deter you (because we almost changed our minds)...go in and try something new!   You'll be glad you did!       1  _7bHUi9Uuf5__HHc_Q8guQ 2015-01-04 00:01:03
# 4  e4Vwtrqf-wpJfwesgvdgxQ     1  2017-01-14 20:54:15      0  Sx8TMOWLNuJBWer-0pcmoA    4.0                                                                                                                                                                                                                                                                                                             Cute interior and owner (?) gave us tour of upcoming patio/rooftop area which will be great on beautiful days like today. Cheese curds were very good and very filling. Really like that sandwiches come w salad, esp after eating too many curds! Had the onion, gruyere, tomato sandwich. Wasn't too much cheese which I liked. Needed something else...pepper jelly maybe. Would like to see more menu options added such as salads w fun cheeses. Lots of beer and wine as well as limited cocktails. Next time I will try one of the draft wines.       1  bcjbaE6dDog4jkNY91ncLQ 2017-01-14 20:54:15

# %%
min_datetime = k_review.datetime.min()
min_datetime
# Out:
# Timestamp('2005-02-16 03:23:22')

# %%
max_datetime = k_review.datetime.max()
max_datetime
# Out:
# Timestamp('2022-01-19 19:48:45')

# %%
min_datetime.time()
# Out:
# datetime.time(3, 23, 22)

# %%
max_datetime.date()
# Out:
# datetime.date(2022, 1, 19)

# %% [markdown]
# Now we separate the hour and date from the datetime column in different columns

# %%
k_review['date'] = k_review.datetime.apply(lambda x: x.date())
# Out:
# /content/spark-3.1.3-bin-hadoop2.7/python/pyspark/sql/pandas/functions.py:392: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   "in the future releases. See SPARK-28264 for more details.", UserWarning)

# %%
def get_time(datetime):
  return datetime.dt.hour()

# %%
k_review['hour'] = k_review.datetime.dt.hour

# %%
k_review.head()
# Out:
#               business_id  cool        date  funny               review_id  stars                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               text  useful                 user_id            datetime  hour
# 0  XQfwVwDr-v0ZS3_CbbE5Xw     0  2018-07-07      0  KU_O5udG6zpxOg-VcAEodg    3.0                                                                                                                                                                                                                                                                                                                                If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to it's other locations in NJ and never had a bad experience. \n\nThe food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.       0  mh_-eMZ6K5RLWhZyISBhwA 2018-07-07 22:09:11    22
# 1  7ATYjTIgM3jUlt4UM3IypQ     1  2012-01-03      0  BiTunyQ73aT9WBnpR9DZGw    5.0  I've taken a lot of spin classes over the years, and nothing compares to the classes at Body Cycle. From the nice, clean space and amazing bikes, to the welcoming and motivating instructors, every class is a top notch work out.\n\nFor anyone who struggles to fit workouts in, the online scheduling system makes it easy to plan ahead (and there's no need to line up way in advanced like many gyms make you do).\n\nThere is no way I can write this review without giving Russell, the owner of Body Cycle, a shout out. Russell's passion for fitness and cycling is so evident, as is his desire for all of his clients to succeed. He is always dropping in to classes to check in/provide encouragement, and is open to ideas and recommendations from anyone. Russell always wears a smile on his face, even when he's kicking your butt in class!       1  OyoGAe7OKpv6SyGZT5g77Q 2012-01-03 15:28:18    15
# 2  YjUWPpI6HXG530lwP-fb2A     0  2014-02-05      0  saUsX_uimxRlCVr67Z4Jig    3.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Family diner. Had the buffet. Eclectic assortment: a large chicken leg, fried jalapeño, tamale, two rolled grape leaves, fresh melon. All good. Lots of Mexican choices there. Also has a menu with breakfast served all day long. Friendly, attentive staff. Good place for a casual relaxed meal with no expectations. Next to the Clarion Hotel.       0  8g_iMtfSiwikVnbP2etR0A 2014-02-05 20:30:30    20
# 3  kxX2SOes4o-D3ZQBkiMRfA     1  2015-01-04      0  AqPFMleE6RsU23_auESxiA    5.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Wow!  Yummy, different,  delicious.   Our favorite is the lamb curry and korma.  With 10 different kinds of naan!!!  Don't let the outside deter you (because we almost changed our minds)...go in and try something new!   You'll be glad you did!       1  _7bHUi9Uuf5__HHc_Q8guQ 2015-01-04 00:01:03     0
# 4  e4Vwtrqf-wpJfwesgvdgxQ     1  2017-01-14      0  Sx8TMOWLNuJBWer-0pcmoA    4.0                                                                                                                                                                                                                                                                                                             Cute interior and owner (?) gave us tour of upcoming patio/rooftop area which will be great on beautiful days like today. Cheese curds were very good and very filling. Really like that sandwiches come w salad, esp after eating too many curds! Had the onion, gruyere, tomato sandwich. Wasn't too much cheese which I liked. Needed something else...pepper jelly maybe. Would like to see more menu options added such as salads w fun cheeses. Lots of beer and wine as well as limited cocktails. Next time I will try one of the draft wines.       1  bcjbaE6dDog4jkNY91ncLQ 2017-01-14 20:54:15    20

# %% [markdown]
# ## --------- COLUMN: text ---------
#
# // string, the review text
#
# "text": "Great place to hang out after work: the prices are decent, and the ambience is fun. It's a bit loud, but very lively. The staff is friendly, and the food is good. They have a good selection of drinks."

# %%
len(k_review.text.unique())
# Out:
# 6974127

# %%
k_review['empty_text'] = k_review.text.apply(is_empty)
# Out:
# /content/spark-3.1.3-bin-hadoop2.7/python/pyspark/sql/pandas/functions.py:392: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   "in the future releases. See SPARK-28264 for more details.", UserWarning)

# %%
k_review.empty_text.value_counts()
# Out:
# 0    6990280
# Name: empty_text, dtype: int64

# %%
def get_word_count(str):
  ls = str.split()
  return len(ls)

# %%
k_review['word_count'] = k_review.text.apply(get_word_count)
# Out:
# /content/spark-3.1.3-bin-hadoop2.7/python/pyspark/sql/pandas/functions.py:392: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   "in the future releases. See SPARK-28264 for more details.", UserWarning)

# %%
k_review['word_count'].describe()
# Out:
# count    6.990280e+06
# mean     1.047763e+02
# std      9.792227e+01
# min      1.000000e+00
# 25%      4.200000e+01
# 50%      7.500000e+01
# 75%      1.330000e+02
# max      1.070000e+03
# Name: word_count, dtype: float64

# %%
len(k_review[k_review.word_count >= 500])
# Out:
# 65090

# %% [markdown]
# ## --------- COLUMN: stars ---------
#
# // integer, star score from 1 to 5
#
# "stars": 4

# %%
# Get the amount of reviews for each possible score

k_review.stars.value_counts()
# Out:
# 5.0    3231627
# 4.0    1452918
# 1.0    1069561
# 3.0     691934
# 2.0     544240
# Name: stars, dtype: int64

# %% [markdown]
# ## --------- COLUMN: useful ---------
#
# // integer, number of votes considering the review 'useful'
#
# "useful": 0

# %%
# Most common values for 'useful' calification on a review

k_review.useful.value_counts().head(15)
# Out:
# 0     3840492
# 1     1539953
# 2      687425
# 3      343742
# 4      186984
# 5      112204
# 6       71214
# 7       47679
# 8       34000
# 9       24783
# 10      18475
# 11      14319
# 12      11103
# 13       8751
# 14       7112
# Name: useful, dtype: int64

# %%
k_review.useful.max()
# Out:
# 1182

# %% [markdown]
# ## --------- COLUMN: funny ---------
#
# // integer, number of votes considering the review 'funny'
# "funny": 0

# %%
# Most common values for 'funny' calification on a review

k_review.funny.value_counts().head(15)
# Out:
# 0     5894117
# 1      691994
# 2      195290
# 3       82111
# 4       42254
# 5       24723
# 6       15545
# 7       10178
# 8        7147
# 9        5223
# 10       3739
# 11       2992
# 12       2367
# 13       1896
# 14       1419
# Name: funny, dtype: int64

# %%
str(k_review[k_review.funny == k_review.funny.max()].text)
# Out:
# '6885693    Went there for a birthday dinner and had reser...\nName: text, dtype: object'

# %% [markdown]
# ## --------- COLUMN: cool ---------
#
#
# // integer, number of votes considering the review 'cool'.
#
# "cool": 0

# %%
# Most common values for 'useful' calification on a review

k_review.cool.value_counts().head(15)
# Out:
# 0     5377964
# 1     1016736
# 2      296999
# 3      114763
# 4       56609
# 5       32352
# 6       21530
# 7       15010
# 8       11028
# 9        8085
# 10       6349
# 11       4981
# 12       4011
# 13       3125
# 14       2549
# Name: cool, dtype: int64

# %%
def get_dtypes(dataset):
  '''
  This function gets the data types present on each column of a dataset.

  :: param dataset: Pandas or Koalas DataFrame

  Return:
  ---------
  Returns a dictionary that contains the data types for each column of a dataset.
  '''
  # npds = dataset.values
  cols = dataset.columns
  types_dict = {}
  for col in cols:
    types_dict[col] = set()
    for value in dataset[col]:
      types_dict[col].add(type(value))
  return types_dict

# %%
len(k_review[k_review.business_id == 'IvQs2hhXKZ4NgZhVZ5jjjQ'])
# Out:
# 5

# %%
k_review[k_review.business_id == 'IvQs2hhXKZ4NgZhVZ5jjjQ']
# Out:
#                     business_id  cool                 date  funny               review_id  stars                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               text  useful                 user_id            datetime
# 4440011  IvQs2hhXKZ4NgZhVZ5jjjQ     0  2008-06-20 13:55:12      0  _wxTSWQpQqi2D2jIQOmhVw    4.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             What a little sandwiches and deli. It serves anything that you could want from a lunch or just a cup of tea and cake. The service is particularly friendly and its always a pleasure to go back there.       0  x82wL_fePhJGUB7_ZbLX2g 2008-06-20 13:55:12
# 4592839  IvQs2hhXKZ4NgZhVZ5jjjQ     0  2010-04-17 18:16:28      0  WDN1QObUHMDgwD603RfBvQ    4.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  When I worked on Rodney Street (ie out of range for Out to Lunch) the sand which shop of choice was always Pumpernickles. The beauty of working in a small office was that we each took it in turn to phone our group order through and then walk down to pick it up at lunch time, so at least once a week I got to feel like I'd worked off my food. \n\nNot quite to the point of queueing round the block yet, this is still a very popular corner shop and you find an unusual variety of builders, suits and students in there. Prices are cheap and staff are efficient - well, they have to be to meet the lunch time rush! A good variety of lunchable munchables means it is easy to understand why this is so popular.       0  xA6GL6xQ-oGBxTa7UMRYAw 2010-04-17 18:16:28
# 4616218  IvQs2hhXKZ4NgZhVZ5jjjQ     0  2010-06-12 11:18:49      0  Lcwp3xHAew7mz9Adh1PMVQ    3.0  Pumpernickles is situated a stones throw away from Langtons sandwich bar and you could make a case for a visit to both. Pumpernickles just like langtons makes a large range of sandwiches and is good for a breakfast sarnie or something a little lighter in the afternoon. Pumpernickles though , from its' name to its decor and signing seems to have a touch more class than Langtons does although the taste of both places produce is very similar. Pumpernickles advertises that it caters for parties and buffets something which as far as I'm aware Langtons does not do. The staff in Pumpernickles are pleasant and the service is quick for waiting customers who often want to grab a quick sandwich and go. Pumpernickles seems to be the slightly more upmarket version of Langtons but unlike Langtons it does not have any outside seating although the shop is slightly larger. I would recommend the BLT at Pumpernickles as I tried it and found it to be perfect, it is a great establishment and one which will provide a top notch barm.\nIt is only natural to compare Langtons' and Pumpernickles but except for the fact that one caters for parties ect and the decor is different you'll find very little difference and my advice would be to simply visit which every you are nearest to at the time as neither will disappoint.       0  ERyhMwXG1woQbBMuK68ZQg 2010-06-12 11:18:49
# 4685310  IvQs2hhXKZ4NgZhVZ5jjjQ     0  2010-06-24 11:26:30      0  WbRCJLvJdO65sHj1LZfOTw    4.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Pumpernickles is situated in a vast student area of town which is easy to see why it is so popular not only with students but for office workers and the rest of the public. Every time I walk past here, the shop tends to be full of queue at peak lunch times. \n\nThey sell sandwiches galore and a generous choice of salads thus making it a quick lunch stop for busy commuters. A good English breakfast is also available, starting from just £3 which you won't find too greasy. Pumpernickles is generally convenient and affordable, that offers a selection of ingredients to suit everyone. There is not much to fault at all and not to forget, it is a healthy option.       0  0pkjvlKAzNZjSVdfNK-GjA 2010-06-24 11:26:30
# 4738676  IvQs2hhXKZ4NgZhVZ5jjjQ     0  2010-06-10 14:52:08      0  gH-7TIQAeLx5grr6G2PHow    4.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Pumpernickles. How very Dickensian. I feel as though Scrooge is going to be working away in the back and the counter staffed by Miss Piggy and Kermit. However, this isn't really the style of the shop just my over-active imagination! (And I know the Muppets weren't in the original A Christmas Carol!) \n\nIt's a lovely little sandwich bar on the corner of Mount Pleasant and my favourite part of the service they offer is a little Packed Lunch; you get a sarnie, drink, and either crisps or fruit for £2.50. Well worth the moolah. Tasty, freshand  healthy! \nMakes me want to buy a Power Rangers lunch box.       0  t-dVBcTV67DqZM5EVy2SVQ 2010-06-10 14:52:08

# %% [markdown]
# ## --------- BUSINESS ---------

# %%
# Import datasets as spark and convert to koalas
business = spark.read.load("/content/drive/MyDrive/HENRY_TRABAJO_GRUPAL/Dataset_Yelp/business.json", format="json")
k_business = business.to_koalas()

# %%
k_business.head()
# Out:
#                            address                                                                                                                                                                                                                                                                                                                         attributes             business_id                                                                                                  categories           city                                                                   hours  is_open   latitude   longitude                      name postal_code  review_count  stars state
# 0           1616 Chapala St, Ste 2                                                                                         (None, None, None, None, None, None, None, None, None, None, None, True, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)  Pns2l4eNsfO8kk83dixA6A  Doctors, Traditional Chinese Medicine, Naturopathic/Holistic, Acupuncture, Health & Medical, Nutritionists  Santa Barbara                                                                    None        0  34.426679 -119.711197  Abby Rappoport, LAC, CMQ       93101             7    5.0    CA
# 1  87 Grasso Plaza Shopping Center                                                                                         (None, None, None, None, None, None, None, None, None, True, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)  mpf3x-BjTdTEA3yCZrAYPw                              Shipping Centers, Local Services, Notaries, Mailbox Centers, Printing Services         Affton   (8:0-18:30, 0:0-0:0, 8:0-14:0, None, 8:0-18:30, 8:0-18:30, 8:0-18:30)        1  38.551126  -90.335695             The UPS Store       63123            15    3.0    MO
# 2             5255 E Broadway Blvd  (None, None, None, None, None, None, None, True, None, True, {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}, False, False, False, None, None, False, None, None, None, None, None, False, False, None, None, None, False, None, None, False, None, 2, False, None, False, None, True, u'no')  tUFrWirKiKi_TAnsVWINQQ                          Department Stores, Shopping, Fashion, Home & Garden, Electronics, Furniture Stores         Tucson  (8:0-23:0, 8:0-22:0, 8:0-23:0, 8:0-22:0, 8:0-22:0, 8:0-22:0, 8:0-22:0)        0  32.223236 -110.880452                    Target       85711            22    3.5    AZ
# 3                      935 Race St   (None, None, u'none', None, None, None, None, True, None, False, {'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}, False, True, None, None, None, None, None, None, None, None, None, None, None, None, None, None, False, None, None, False, None, 1, None, None, True, None, None, u'free')  MTSW4McQd7CbVtyjqoe9mw                                                       Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries   Philadelphia  (7:0-21:0, 7:0-20:0, 7:0-21:0, 7:0-21:0, 7:0-20:0, 7:0-20:0, 7:0-20:0)        1  39.955505  -75.155564        St Honore Pastries       19107            80    4.0    PA
# 4                    101 Walnut St            (None, None, None, None, None, None, None, True, None, True, {'garage': None, 'street': None, 'validated': None, 'lot': True, 'valet': False}, None, False, None, None, None, None, None, None, True, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, True, None, True, None)  mWMc6_wTdE0EUBKIGXDVfA                                                                                   Brewpubs, Breweries, Food     Green Lane     (12:0-22:0, None, 12:0-22:0, 12:0-18:0, 16:0-22:0, None, 14:0-22:0)        1  40.338183  -75.471659  Perkiomen Valley Brewery       18054            13    4.5    PA

# %%
k_business.dtypes
# Out:
# address          object
# attributes       object
# business_id      object
# categories       object
# city             object
# hours            object
# is_open           int64
# latitude        float64
# longitude       float64
# name             object
# postal_code      object
# review_count      int64
# stars           float64
# state            object
# dtype: object

# %%
k_business.categories
# Out:
# 0      Doctors, Traditional Chinese Medicine, Naturop...
# 1      Shipping Centers, Local Services, Notaries, Ma...
# 2      Department Stores, Shopping, Fashion, Home & G...
# 3      Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                              Brewpubs, Breweries, Food
# 5      Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 6      Sporting Goods, Fashion, Shoe Stores, Shopping...
# 7                    Synagogues, Religious Organizations
# 8      Pubs, Restaurants, Italian, Bars, American (Tr...
# 9      Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 10                  Department Stores, Shopping, Fashion
# 11            Vietnamese, Food, Restaurants, Food Trucks
# 12     American (Traditional), Restaurants, Diners, B...
# 13     General Dentistry, Dentists, Health & Medical,...
# 14           Food, Delis, Italian, Bakeries, Restaurants
# 15                     Sushi Bars, Restaurants, Japanese
# 16     Automotive, Auto Parts & Supplies, Auto Custom...
# 17     Vape Shops, Tobacco Shops, Personal Shopping, ...
# 18     Automotive, Car Rental, Hotels & Travel, Truck...
# 19                                   Korean, Restaurants
# 20     Coffee & Tea, Food, Cafes, Bars, Wine Bars, Re...
# 21      Shopping, Books, Mags, Music & Video, Bookstores
# 22                Steakhouses, Asian Fusion, Restaurants
# 23                                  Restaurants, Italian
# 24                                 Hot Dogs, Restaurants
# 25       Pet Services, Pet Groomers, Pets, Veterinarians
# 26     Women's Clothing, Accessories, Children's Clot...
# 27                        Restaurants, Japanese, Seafood
# 28     Cocktail Bars, Bars, Italian, Nightlife, Resta...
# 29         Pizza, Chicken Wings, Sandwiches, Restaurants
# 30                         Trampoline Parks, Active Life
# 31                       Pizza, Restaurants, Salad, Soup
# 32     Dance Wear, Sports Wear, Children's Clothing, ...
# 33                                    Pizza, Restaurants
# 34     Event Planning & Services, Hotels, Hotels & Tr...
# 35     Eatertainment, Arts & Entertainment, Brewpubs,...
# 36                                  Restaurants, Burgers
# 37     Mobile Phones, Telecommunications, Electronics...
# 38     Museums, Kids Activities, Arts & Entertainment...
# 39     Musicians, DJs, Karaoke, Event Planning & Serv...
# 40     Hair Salons, Hair Extensions, Beauty & Spas, W...
# 41     Restaurants, Specialty Food, Steakhouses, Food...
# 42     DUI Law, Professional Services, Lawyers, Crimi...
# 43     Health & Medical, Beauty & Spas, Laser Hair Re...
# 44     Fashion, Shopping, Department Stores, Furnitur...
# 45                                  Restaurants, Chinese
# 46     Arts & Entertainment, Music Venues, Internet S...
# 47     Coffee & Tea, Restaurants, Wine Bars, Bars, Ni...
# 48                      Shipping Centers, Local Services
# 49                                  Restaurants, Italian
# 50     Active Life, Fitness & Instruction, Trainers, ...
# 51        Real Estate Agents, Home Services, Real Estate
# 52        Specialty Food, Bakeries, Food, Health Markets
# 53     Coffee & Tea, Cafes, Pets, Restaurants, Pet Ad...
# 54                     Food, Grocery, Convenience Stores
# 55     Hotels, Hotels & Travel, Event Planning & Serv...
# 56     Vitamins & Supplements, Ice Cream & Frozen Yog...
# 57     Ophthalmologists, Eyewear & Opticians, Health ...
# 58                  Restaurants, American (New), Italian
# 59                                    Restaurants, Pizza
# 60                   Restaurants, Soup, Seafood, Burgers
# 61     Sports Bars, American (New), American (Traditi...
# 62     Gastropubs, Cocktail Bars, Beer Bar, Bars, Res...
# 63                                    Uniforms, Shopping
# 64     Seafood, Restaurants, Bars, Nightlife, Cocktai...
# 65                  Hotels & Travel, Tours, Local Flavor
# 66                   Local Services, Appliances & Repair
# 67     Towing, Hotels & Travel, Automotive, Motorcycl...
# 68     Chocolatiers & Shops, Specialty Food, Candy St...
# 69                                         Food, Grocery
# 70                                     Food Trucks, Food
# 71     Shopping, Baby Gear & Furniture, Home Decor, F...
# 72             Banks & Credit Unions, Financial Services
# 73     American (Traditional), Bars, Nightlife, Sport...
# 74     Health & Medical, Personal Care Services, Beau...
# 75     American (Traditional), Sports Bars, Restauran...
# 76                                         Food, Grocery
# 77              Tabletop Games, Shopping, Sporting Goods
# 78                                  Italian, Restaurants
# 79     Burgers, Sports Bars, Bars, Lounges, Restauran...
# 80                       Festivals, Arts & Entertainment
# 81                 Food, Beer, Wine & Spirits, Breweries
# 82     Restaurants, Automotive, Delis, Gas Stations, ...
# 83       Restaurants, Japanese, Sushi Bars, Asian Fusion
# 84      Keys & Locksmiths, Home Services, Local Services
# 85     Food, Restaurants, Salad, Coffee & Tea, Breakf...
# 86         Pet Groomers, Pet Sitting, Pets, Pet Services
# 87     Nightlife, Pubs, Event Planning & Services, Wi...
# 88     Juice Bars & Smoothies, Restaurants, Fruits & ...
# 89     Ice Cream & Frozen Yogurt, Coffee & Tea, Resta...
# 90     Home Decor, Shopping, Antiques, Books, Mags, M...
# 91                        Towing, Automotive, Body Shops
# 92                     Fashion, Shopping, Men's Clothing
# 93               Restaurants, Italian, Food Trucks, Food
# 94     Masonry/Concrete, Gardeners, Lawn Services, Tr...
# 95     Karaoke, DJs, Event Planning & Services, Party...
# 96     Event Planning & Services, Caterers, Party & E...
# 97     Sporting Goods, Sports Wear, Fashion, Restaura...
# 98     Real Estate, Home Services, Financial Services...
# 99     American (New), Restaurants, Cafes, Italian, A...
# 100    Fitness & Instruction, Physical Therapy, Healt...
# 101    Women's Clothing, Men's Clothing, Accessories,...
# 102                                 Seafood, Restaurants
# 103                   Restaurants, Seafood, Cajun/Creole
# 104                                 Mexican, Restaurants
# 105    Printing Services, Local Services, Shipping Ce...
# 106    Restaurants, French, Moroccan, Seafood, Medite...
# 107       Flooring, Handyman, Contractors, Home Services
# 108                         Pest Control, Local Services
# 109                Shopping, Auction Houses, Active Life
# 110    Bars, Lounges, American (New), Restaurants, Ni...
# 111    Eyewear & Opticians, Health & Medical, Shoppin...
# 112    Bars, Beer Gardens, Food, Breweries, Nightlife...
# 113                         Juice Bars & Smoothies, Food
# 114    Grocery, Food, Shopping, Fashion, Drugstores, ...
# 115                        Eyewear & Opticians, Shopping
# 116              Public Services & Government, Libraries
# 117                                        Grocery, Food
# 118    Flowers & Gifts, Embroidery & Crochet, Uniform...
# 119    Couriers & Delivery Services, Local Services, ...
# 120    Parenting Classes, Maternity Wear, Fashion, Ed...
# 121            Furniture Stores, Shopping, Home & Garden
# 122                   Sandwiches, Fast Food, Restaurants
# 123                               Barbers, Beauty & Spas
# 124    Home Services, Glass & Mirrors, Door Sales/Ins...
# 125    Hardware Stores, Home Services, Hot Tub & Pool...
# 126                                   Pizza, Restaurants
# 127    Tires, Auto Repair, Oil Change Stations, Autom...
# 128    Medical Centers, Doctors, Diagnostic Services,...
# 129    Nightlife, Chicken Wings, Pubs, Bars, American...
# 130                                 Restaurants, Chinese
# 131    Cocktail Bars, Italian, Nightlife, Seafood, Ba...
# 132            Bars, Restaurants, Sports Bars, Nightlife
# 133    Custom Cakes, Food, Desserts, Cupcakes, Ice Cr...
# 134    Discount Store, Department Stores, Food, Drugs...
# 135                 Car Wash, Auto Detailing, Automotive
# 136    Auto Repair, Automotive, Tires, Oil Change Sta...
# 137    Pain Management, Doctors, Health & Medical, Os...
# 138    Title Loans, Installment Loans, Financial Serv...
# 139    Food, Organic Stores, Specialty Food, Health M...
# 140    Desserts, Do-It-Yourself Food, Food, Patisseri...
# 141    Live/Raw Food, Restaurants, Seafood, Beer Bar,...
# 142       Real Estate, Home Services, Real Estate Agents
# 143    Buses, Transportation, Bus Tours, Hotels & Tra...
# 144                           Food, Beer, Wine & Spirits
# 145                                Restaurants, Filipino
# 146         Doctors, Internal Medicine, Health & Medical
# 147                                       Food, Desserts
# 148                                  Pets, Veterinarians
# 149                    Fashion, Shopping, Men's Clothing
# 150                                    Shopping, Fashion
# 151           Seafood, Restaurants, Sushi Bars, Japanese
# 152    Shopping, Books, Mags, Music & Video, Toy Stor...
# 153                      Mexican, Fast Food, Restaurants
# 154    Painters, Home Services, Decks & Railing, Cont...
# 155    Hotels, Hotels & Travel, Bed & Breakfast, Even...
# 156    Massage, Health & Medical, Medical Spas, Beaut...
# 157                                        Food, Grocery
# 158            Banks & Credit Unions, Financial Services
# 159                Nightlife, Restaurants, Bars, Mexican
# 160                               Body Shops, Automotive
# 161                      Burgers, Restaurants, Fast Food
# 162    Art Classes, Shopping, Education, Arts & Craft...
# 163                     Gas Stations, Automotive, Towing
# 164                  Event Planning & Services, Caterers
# 165                                Restaurants, Barbeque
# 166                        Health & Medical, Urgent Care
# 167                                 Italian, Restaurants
# 168    Active Life, Basketball Courts, Stadiums & Are...
# 169    Pharmacy, Health & Medical, Convenience Stores...
# 170                                Beauty & Spas, Tattoo
# 171    Home & Garden, Music & DVDs, Fashion, Accessor...
# 172    Oil Change Stations, Automotive, Tires, Auto R...
# 173    Waxing, Hair Removal, Skin Care, Eyelash Servi...
# 174    Weight Loss Centers, Health & Medical, Life Co...
# 175                  Auto Repair, Body Shops, Automotive
# 176    Home Cleaning, Home Services, Office Cleaning,...
# 177      Active Life, Playgrounds, Parks, Swimming Pools
# 178                      Health & Medical, Chiropractors
# 179    Beauty & Spas, Hair Stylists, Hair Extensions,...
# 180                        Dog Parks, Active Life, Parks
# 181    Venues & Event Spaces, Performing Arts, Arts &...
# 182    Food, Ice Cream & Frozen Yogurt, Desserts, Sha...
# 183    Home & Garden, Local Services, Appliances, App...
# 184                    Medical Centers, Health & Medical
# 185                                Restaurants, Barbeque
# 186                    Japanese, Sushi Bars, Restaurants
# 187                                   Coffee & Tea, Food
# 188     Fast Food, Sandwiches, Chicken Shop, Restaurants
# 189        Restaurants, Sandwiches, Pizza, Chicken Wings
# 190                                        Grocery, Food
# 191                                   Pizza, Restaurants
# 192    Shopping, Department Stores, Grocery, Fashion,...
# 193    Fast Food, Restaurants, Food, Burgers, Coffee ...
# 194       Wildlife Control, Local Services, Pest Control
# 195      Apartments, Roofing, Real Estate, Home Services
# 196                 Bars, Wine Bars, Nightlife, Beer Bar
# 197    Home Services, Vacation Rentals, Real Estate, ...
# 198    Restaurants, American (New), Burgers, Fast Foo...
# 199                      Burgers, Restaurants, Fast Food
# 200                 Japanese, Chinese, Restaurants, Thai
# 201    Auto Glass Services, Automotive, Windshield In...
# 202    Restaurants, Bakeries, Caterers, Bagels, Food,...
# 203                                  Pets, Veterinarians
# 204    Endodontists, General Dentistry, Health & Medi...
# 205                                   Food, Coffee & Tea
# 206                      Restaurants, Breakfast & Brunch
# 207                              Plumbing, Home Services
# 208    Carpeting, Shopping, Home Services, Flooring, ...
# 209    Arts & Entertainment, Nightlife, Jazz & Blues,...
# 210               Real Estate, Apartments, Home Services
# 211    Hotels & Travel, Event Planning & Services, Ho...
# 212    Makeup Artists, Beauty & Spas, Hair Salons, Ha...
# 213    American (Traditional), Restaurants, Burgers, ...
# 214                               Barbers, Beauty & Spas
# 215    Health & Medical, Doctors, Medical Centers, Lo...
# 216                                 Toy Stores, Shopping
# 217    Carpet Cleaning, Rugs, Shopping, Flooring, Loc...
# 218                                         Donuts, Food
# 219    Motorcycle Rental, Tours, Hiking, Mountain Bik...
# 220       Drugstores, Convenience Stores, Food, Shopping
# 221       Steakhouses, Restaurants, Sushi Bars, Japanese
# 222    Hawaiian, Food, Food Trucks, Street Vendors, R...
# 223                         Home Services, Tree Services
# 224    Bars, Pubs, Nightlife, Arts & Entertainment, I...
# 225    Trailer Dealers, Auto Parts & Supplies, Auto R...
# 226             Doctors, Pediatricians, Health & Medical
# 227    Professional Services, Officiants, Event Plann...
# 228    Bars, Lounges, Nightlife, Pizza, Restaurants, ...
# 229                  Restaurants, American (Traditional)
# 230    Automotive, Auto Detailing, Car Wash, Auto Gla...
# 231    American (New), Food, Bars, Nightlife, Lounges...
# 232    Car Dealers, Automotive, Used Car Dealers, Aut...
# 233     Beauty & Spas, Hair Removal, Day Spas, Skin Care
# 234    Sports Bars, Bars, Nightlife, Italian, Restaur...
# 235    Restaurants, Breakfast & Brunch, Vegan, Bagels...
# 236                                        Grocery, Food
# 237    Local Services, Shipping Centers, Notaries, Pr...
# 238    Discount Store, Shopping, Event Planning & Ser...
# 239                                    Shopping, Jewelry
# 240    Specialty Food, Food, Shaved Ice, Juice Bars &...
# 241                                    Tires, Automotive
# 242               Salad, Restaurants, Burgers, Soul Food
# 243               Home Services, Real Estate, Apartments
# 244      Appliances, Mattresses, Shopping, Home & Garden
# 245    Restaurants, Italian, Nightlife, Bars, Cocktai...
# 246    Local Flavor, Team Building Activities, Active...
# 247    Restaurants, Lounges, Bars, American (New), Ni...
# 248    Machine Shops, Local Services, Automotive, Aut...
# 249    Shanghainese, Restaurants, Sushi Bars, Szechua...
# 250     Beauty & Spas, Waxing, Nail Salons, Hair Removal
# 251                      Pet Services, Pet Sitting, Pets
# 252    Cupcakes, Street Vendors, Food Delivery Servic...
# 253      Pizza, Restaurants, Bars, Nightlife, Sandwiches
# 254       Irish Pub, Bars, Restaurants, Irish, Nightlife
# 255    Fitness & Instruction, Gyms, Weight Loss Cente...
# 256    Restaurants, Breakfast & Brunch, Coffee Roaste...
# 257    Drugstores, Pharmacy, Health & Medical, Conven...
# 258                      Restaurants, Breakfast & Brunch
# 259    Event Planning & Services, Hotels, Hotels & Tr...
# 260    Health & Medical, Doctors, Endocrinologists, I...
# 261    Shopping, Fashion, Outdoor Gear, Active Life, ...
# 262    Active Life, Fitness & Instruction, Trainers, ...
# 263    Active Life, Shopping, Fishing, Hunting & Fish...
# 264           Italian, Chicken Wings, Pizza, Restaurants
# 265    Diagnostic Imaging, Diagnostic Services, Healt...
# 266                          Food, Bakeries, Restaurants
# 267                    Fashion, Men's Clothing, Shopping
# 268    Hotels, Rest Stops, Event Planning & Services,...
# 269      Professional Sports Teams, Arts & Entertainment
# 270    Home Services, Professional Services, Home Cle...
# 271                       Chinese, Restaurants, Filipino
# 272            Shopping, Furniture Stores, Home & Garden
# 273    Mountain Biking, Bike Repair/Maintenance, Shop...
# 274    Cupcakes, Caribbean, Restaurants, Trinidadian,...
# 275                    Restaurants, Sushi Bars, Japanese
# 276    Tex-Mex, Restaurants, American (Traditional), ...
# 277               Apartments, Real Estate, Home Services
# 278                                 Mexican, Restaurants
# 279                               Body Shops, Automotive
# 280                      Beauty & Spas, Piercing, Tattoo
# 281    Orthodontists, Health & Medical, Oral Surgeons...
# 282    Event Planning & Services, Party & Event Plann...
# 283    Bike Rentals, Active Life, Bikes, Shopping, Sp...
# 284    Italian, Pizza, Gluten-Free, Restaurants, Bars...
# 285    Health & Medical, Medical Spas, Beauty & Spas,...
# 286               Real Estate, Apartments, Home Services
# 287                               Barbers, Beauty & Spas
# 288    Tours, Walking Tours, Hotels & Travel, Food Tours
# 289    Photography Stores & Services, Beauty & Spas, ...
# 290                 Latin American, Mexican, Restaurants
# 291            Caribbean, Food, Restaurants, Food Trucks
# 292    Italian, Restaurants, Salad, Bars, Venues & Ev...
# 293                                 Burgers, Restaurants
# 294    Makeup Artists, Blow Dry/Out Services, Beauty ...
# 295    Men's Hair Salons, Waxing, Hair Salons, Skin C...
# 296    Italian, Seafood, American (Traditional), Stea...
# 297    Nightlife, Bars, Cocktail Bars, Japanese, Rest...
# 298    Event Planning & Services, Hotels & Travel, Ho...
# 299                           Beauty & Spas, Hair Salons
# 300                Performing Arts, Arts & Entertainment
# 301    Sandwiches, Chicken Wings, Restaurants, Donuts...
# 302                      Beauty & Spas, Tattoo, Piercing
# 303                  Home Services, Windows Installation
# 304    Arts & Crafts, Sports Wear, Costumes, Performi...
# 305              Nail Salons, Beauty & Spas, Hair Salons
# 306    Flooring, Home Services, Carpeting, Contractor...
# 307    Shoe Repair, Sewing & Alterations, Local Services
# 308               Thai, Vietnamese, Chinese, Restaurants
# 309    Shipping Centers, Notaries, Local Services, Pr...
# 310    Men's Clothing, Women's Clothing, Children's C...
# 311              Radiologists, Doctors, Health & Medical
# 312    Ethnic Food, Specialty Food, Restaurants, Food...
# 313                       Chinese, Restaurants, Japanese
# 314    Beauty & Spas, Eyelash Service, Skin Care, Tan...
# 315                              Restaurants, Sandwiches
# 316    Restaurants, Acai Bowls, Vegan, Organic Stores...
# 317    Restaurants, Cajun/Creole, Southern, Nightlife...
# 318                     Pet Services, Pets, Pet Training
# 319    Restaurants, Salad, Pakistani, Indian, Cocktai...
# 320    Street Vendors, Food, Food Trucks, Greek, Food...
# 321    Local Flavor, Public Art, Museums, Nightlife, ...
# 322    Education, Preschools, Local Services, Child C...
# 323                               Massage, Beauty & Spas
# 324    Convenience Stores, Food, Grocery, Coffee & Te...
# 325                    Steakhouses, Burgers, Restaurants
# 326            Home & Garden, Furniture Stores, Shopping
# 327    Playgrounds, Kids Activities, Active Life, Par...
# 328    Sewing & Alterations, Local Services, Dry Clea...
# 329                              Auto Repair, Automotive
# 330                                 Car Wash, Automotive
# 331                  Animal Shelters, Pet Adoption, Pets
# 332        Chicken Wings, Sandwiches, Restaurants, Pizza
# 333    Specialty Food, Restaurants, Food, Seafood, Se...
# 334    Automotive, Propane, Movers, Self Storage, Tow...
# 335                                  Pets, Veterinarians
# 336    Financial Services, Insurance, Check Cashing/P...
# 337                             Food, Bakeries, Desserts
# 338                           Food, Beer, Wine & Spirits
# 339    Salad, Hot Dogs, Burgers, Restaurants, America...
# 340    Nightlife, Pubs, American (Traditional), Resta...
# 341                        Guest Houses, Hotels & Travel
# 342        Flooring, Refinishing Services, Home Services
# 343                    Italian, Restaurants, Steakhouses
# 344    Tires, Automotive, Auto Repair, Oil Change Sta...
# 345         Restaurants, Mexican, American (Traditional)
# 346    Electronics, Musical Instruments & Teachers, S...
# 347                                   Towing, Automotive
# 348                          Mexican, Pizza, Restaurants
# 349                    Churches, Religious Organizations
# 350    Historical Tours, Tours, Hotels & Travel, Food...
# 351                                 Restaurants, Mexican
# 352    Pizza, Fast Food, Gluten-Free, Restaurants, Salad
# 353    Arts & Entertainment, Event Planning & Service...
# 354    Child Care & Day Care, Education, Local Servic...
# 355    Bars, Pubs, Nightlife, Restaurants, American (...
# 356    Local Services, Community Service/Non-Profit, ...
# 357                                   Food, Coffee & Tea
# 358    American (Traditional), Active Life, Nightlife...
# 359                          Car Rental, Hotels & Travel
# 360                                 Restaurants, Burgers
# 361    Restaurants, Fast Food, Burgers, Food, Coffee ...
# 362                           Beauty & Spas, Nail Salons
# 363    Home & Garden, Countertop Installation, Cabine...
# 364                     Day Spas, Massage, Beauty & Spas
# 365                               Restaurants, Fast Food
# 366                              Sandwiches, Restaurants
# 367    Food, Desserts, Shopping, Specialty Food, Cand...
# 368    Shopping, Home Decor, Flooring, Home Services,...
# 369    Fashion, Discount Store, Sporting Goods, Milit...
# 370      Restaurants, Indian, Buffets, Diners, Pakistani
# 371     Food, Coffee & Tea, Bakeries, Restaurants, Cafes
# 372    Restaurants, American (New), Breakfast & Brunc...
# 373                                   Pizza, Restaurants
# 374    Eyewear & Opticians, Sporting Goods, Shopping,...
# 375                     Home Services, Keys & Locksmiths
# 376    Food, Convenience Stores, Restaurants, Food De...
# 377    Day Spas, Skin Care, Eyebrow Services, Hair Lo...
# 378                      Barbeque, Restaurants, Hot Dogs
# 379    Carpet Cleaning, Local Services, Home Services...
# 380    Doctors, Health & Medical, Urgent Care, Walk-i...
# 381    Event Planning & Services, Restaurants, Empana...
# 382                                 Bowling, Active Life
# 383    Food, Ethnic Food, Specialty Food, Restaurants...
# 384    Shopping, Hardware Stores, Appliances, Buildin...
# 385    Nightlife, Venues & Event Spaces, Performing A...
# 386                          American (New), Restaurants
# 387                          Restaurants, Middle Eastern
# 388                               Beauty & Spas, Barbers
# 389    Shopping, Food, Arts & Entertainment, Wholesal...
# 390                        Active Life, Parks, Dog Parks
# 391    Restaurants, Italian, Nightlife, Southern, Bar...
# 392        Pizza, Chicken Wings, Restaurants, Sandwiches
# 393                              Auto Repair, Automotive
# 394     Coffee & Tea, Restaurants, Food, Cafes, Bakeries
# 395    Food, Wholesalers, Coffee Roasteries, Professi...
# 396                               Beauty & Spas, Massage
# 397    Active Life, Gyms, Fitness & Instruction, Trai...
# 398    Barbers, Education, Hair Salons, Cosmetology S...
# 399            Health & Medical, Dermatologists, Doctors
# 400    Health & Medical, Obstetricians & Gynecologist...
# 401    Mexican, Beer Bar, Bars, Sports Bars, Nightlif...
# 402                            Active Life, Escape Games
# 403                Sandwiches, Restaurants, Pizza, Salad
# 404                               Barbers, Beauty & Spas
# 405    Pet Sitting, Veterinarians, Pet Services, Pet ...
# 406    Community Service/Non-Profit, Shopping, Local ...
# 407      Shopping, Vape Shops, Head Shops, Tobacco Shops
# 408    Puerto Rican, Caribbean, Latin American, Resta...
# 409                                  Korean, Restaurants
# 410                         Self Storage, Local Services
# 411                    Auto Parts & Supplies, Automotive
# 412    Arts & Entertainment, Shopping, Art Galleries,...
# 413    Pets, Pet Groomers, Pet Training, Pet Services...
# 414    Arts & Crafts, Art Galleries, Arts & Entertain...
# 415           Japanese, Restaurants, Sushi Bars, Chinese
# 416        General Dentistry, Dentists, Health & Medical
# 417    Home & Garden, Kitchen & Bath, Shopping, Speci...
# 418     Event Planning & Services, Venues & Event Spaces
# 419    Eyewear & Opticians, Shopping, Health & Medica...
# 420                                Bars, Nightlife, Pubs
# 421    Shopping, Hair Salons, Professional Services, ...
# 422    Caterers, Event Planning & Services, Sandwiche...
# 423    Beauty & Spas, Shopping, Cosmetics & Beauty Su...
# 424    Grocery, Food, Wholesale Stores, Fashion, Shop...
# 425    Masonry/Concrete, Gardeners, Tree Services, La...
# 426    Windows Installation, Home Services, Door Sale...
# 427    Seafood Markets, Seafood, Specialty Food, Food...
# 428                              Automotive, Auto Repair
# 429    Watches, Jewelry Repair, Local Services, Shopp...
# 430    Festivals, Arts & Entertainment, Local Flavor,...
# 431                                   Pizza, Restaurants
# 432           Active Life, Parasailing, Beaches, Boating
# 433    Fitness & Instruction, Food, Shopping, Health ...
# 434    Eyebrow Services, Hair Salons, Makeup Artists,...
# 435            Restaurants, Caribbean, Food Trucks, Food
# 436    Desserts, Specialty Food, Food, Chocolatiers &...
# 437    Carpenters, Pressure Washers, Wallpapering, Ho...
# 438              Food, Mexican, Restaurants, Food Trucks
# 439    Baby Gear & Furniture, Fashion, Appliances, Wo...
# 440    Restaurants, Thai, Food, Specialty Food, Ethni...
# 441        Sandwiches, Cafes, Burgers, Food, Restaurants
# 442       Home Services, Heating & Air Conditioning/HVAC
# 443    Event Planning & Services, Whiskey Bars, Ameri...
# 444                             Nightlife, Lounges, Bars
# 445                                 Restaurants, Chinese
# 446    American (Traditional), Restaurants, Diners, B...
# 447    Session Photography, Photographers, Pets, Pet ...
# 448                              Plumbing, Home Services
# 449       Sporting Goods, Shoe Stores, Shopping, Fashion
# 450                              Sandwiches, Restaurants
# 451    Books, Mags, Music & Video, Comic Books, Shopp...
# 452    Shopping, Electronics Repair, Local Services, ...
# 453    Pet Groomers, Pet Sitting, Pets, Pet Services,...
# 454    Pest Control, Wildlife Control, Local Services...
# 455               Health & Medical, Urgent Care, Doctors
# 456    Home Decor, Arts & Crafts, Kids Activities, Pa...
# 457                                 Restaurants, Chinese
# 458                            Doctors, Health & Medical
# 459                               Barbers, Beauty & Spas
# 460    Food, Burgers, Restaurants, Coffee & Tea, Fast...
# 461    Coffee & Tea, Restaurants, American (New), Foo...
# 462                  Appliances & Repair, Local Services
# 463                          Local Services, Shoe Repair
# 464                              Automotive, Auto Repair
# 465                              Automotive, Car Dealers
# 466    Building Supplies, Shopping, Home & Garden, Ho...
# 467                       Pubs, Nightlife, Bars, Karaoke
# 468            Hospitals, Health & Medical, Optometrists
# 469          Auto Repair, Automotive, Auto Customization
# 470    Burgers, Cafes, Restaurants, Mexican, American...
# 471                              Automotive, Car Dealers
# 472                                  Restaurants, French
# 473    Fashion, Sewing & Alterations, Leather Goods, ...
# 474    Food, Fast Food, Sandwiches, Restaurants, Amer...
# 475                Latin American, Honduran, Restaurants
# 476       American (New), Sandwiches, Restaurants, Pizza
# 477    Keys & Locksmiths, Professional Services, Secu...
# 478    Beauty & Spas, Nutritionists, Medical Spas, La...
# 479    Gastropubs, Nightlife, Restaurants, Thai, Bars...
# 480        Pet Services, Pet Groomers, Pet Sitting, Pets
# 481    Chicken Wings, Italian, Salad, Pizza, Restaurants
# 482    Hotels, Hotels & Travel, Event Planning & Serv...
# 483                 Day Spas, Beauty & Spas, Hair Salons
# 484    Weight Loss Centers, Food, Health Markets, Hea...
# 485                                 Drugstores, Shopping
# 486                               Body Shops, Automotive
# 487    Hair Salons, Barbers, Beauty & Spas, Men's Hai...
# 488                           Beauty & Spas, Hair Salons
# 489    Hair Salons, Hair Stylists, Beauty & Spas, Hai...
# 490    Contractors, Home Services, Septic Services, L...
# 491    Hair Salons, Eyebrow Services, Waxing, Hair Ex...
# 492    Self Storage, Local Services, Automotive, Towi...
# 493                                  Pets, Veterinarians
# 494               Home Services, Real Estate, Apartments
# 495    Automotive, Car Dealers, Auto Detailing, Auto ...
# 496    Italian, Restaurants, Fast Food, Chicken Wings...
# 497    Home Services, Tree Services, Junk Removal & H...
# 498    Hotels, Event Planning & Services, Hotels & Tr...
# 499    Hair Salons, Makeup Artists, Blow Dry/Out Serv...
# 500                              Mobile Phones, Shopping
# 501           Restaurants, Chicken Shop, Ramen, Japanese
# 502    Restaurants, Food, Bagels, Breakfast & Brunch,...
# 503    Preschools, Education, Local Services, Child C...
# 504                        Bars, Local Flavor, Nightlife
# 505    Auto Repair, Oil Change Stations, Auto Parts &...
# 506                  Vietnamese, Sandwiches, Restaurants
# 507    Party & Event Planning, Event Planning & Servi...
# 508    Shopping, Cannabis Collective, Cannabis Clinic...
# 509    Food, American (Traditional), Fast Food, Ice C...
# 510    Automotive, Auto Repair, Tires, Body Shops, Oi...
# 511    Automotive, Auto Repair, Towing, Body Shops, O...
# 512         Oil Change Stations, Auto Repair, Automotive
# 513    Home Window Tinting, Car Window Tinting, Auto ...
# 514    Food, Restaurants, Coffee & Tea, Burgers, Fast...
# 515                      Sporting Goods, Bikes, Shopping
# 516    Automotive, Oil Change Stations, Transmission ...
# 517                        Health & Medical, Urgent Care
# 518                                  Restaurants, Indian
# 519    Auto Parts & Supplies, Automotive, Auto Repair...
# 520                               Barbers, Beauty & Spas
# 521                                   Antiques, Shopping
# 522    Shopping, Furniture Stores, Antiques, Home & G...
# 523                                  Indian, Restaurants
# 524    Restaurants, Cocktail Bars, American (New), De...
# 525                             Carpeting, Home Services
# 526    Event Planning & Services, American (Tradition...
# 527    Veterinarians, Pet Stores, Pets, Pet Photograp...
# 528    Specialty Schools, Education, Gyms, Sports Clu...
# 529                      Restaurants, Fast Food, Burgers
# 530                                Beauty & Spas, Tattoo
# 531    Car Stereo Installation, Shopping, Electronics...
# 532                           Hair Salons, Beauty & Spas
# 533                           Beauty & Spas, Nail Salons
# 534    Women's Clothing, Bespoke Clothing, Sewing & A...
# 535                           Landscaping, Home Services
# 536    Bagels, Food, Breakfast & Brunch, Coffee & Tea...
# 537    Bars, Breakfast & Brunch, Restaurants, America...
# 538    Weight Loss Centers, Health & Medical, Beauty ...
# 539    Active Life, Event Planning & Services, Escape...
# 540                       Beauty & Spas, Eyelash Service
# 541    Restaurants, Seafood, Breakfast & Brunch, Amer...
# 542                           Beer, Wine & Spirits, Food
# 543           Shopping, Home & Garden, Home Decor, Props
# 544    Shopping, Fashion, Men's Clothing, Children's ...
# 545                                 Chinese, Restaurants
# 546    Real Estate, Apartments, Home Services, Local ...
# 547    Health & Medical, Beauty & Spas, Skin Care, Ac...
# 548    Dry Cleaning & Laundry, Local Services, Laundr...
# 549                                Restaurants, Barbeque
# 550                              Arts & Crafts, Shopping
# 551    American (Traditional), Bars, Breakfast & Brun...
# 552          Cajun/Creole, Seafood, Noodles, Restaurants
# 553    Food Trucks, Restaurants, Caterers, Event Plan...
# 554    Mediterranean, Lounges, Bars, Nightlife, Resta...
# 555    Food, Restaurants, Chinese, Bubble Tea, Vietna...
# 556                           Coffee & Tea, Donuts, Food
# 557    American (Traditional), Music Venues, Restaura...
# 558    Shoe Stores, Fashion, Shopping, Formal Wear, A...
# 559    American (New), Barbeque, Restaurants, Burgers...
# 560                      Tattoo, Piercing, Beauty & Spas
# 561    Bagels, Restaurants, Caterers, Sandwiches, Eve...
# 562    Hair Extensions, Hair Salons, Hair Stylists, B...
# 563    Arts & Entertainment, Venues & Event Spaces, E...
# 564                         Self Storage, Local Services
# 565    Home Decor, Home & Garden, Gift Shops, Shoppin...
# 566                                  Indian, Restaurants
# 567    Beauty & Spas, Hair Removal, Skin Care, Waxing...
# 568                       Pakistani, Indian, Restaurants
# 569    Restaurants, Caterers, Barbeque, American (Tra...
# 570                        Grocery, Food, Farmers Market
# 571    Breakfast & Brunch, Coffee & Tea, Sandwiches, ...
# 572                           Food, Donuts, Coffee & Tea
# 573    Event Planning & Services, Hotels, Hotels & Tr...
# 574    Food, Cafes, Restaurants, Coffee & Tea, Breakf...
# 575                    Local Services, Printing Services
# 576                  Italian, Spanish, Restaurants, Food
# 577        Local Flavor, Arts & Entertainment, Festivals
# 578                    Automotive, Auto Parts & Supplies
# 579    Orthodontists, Health & Medical, Pediatric Den...
# 580    Home & Garden, Home Decor, Mattresses, Shoppin...
# 581    Beauty & Spas, Hair Salons, Waxing, Nail Salon...
# 582    Nutritionists, Weight Loss Centers, Health & M...
# 583                                 Mexican, Restaurants
# 584                      Ice Cream & Frozen Yogurt, Food
# 585    Health & Medical, Beauty & Spas, Massage Thera...
# 586    Shopping, Furniture Stores, Rugs, Home & Garde...
# 587    Bakeries, Imported Food, Food, Ethnic Food, Sp...
# 588    Walking Tours, Tours, Hotels & Travel, Histori...
# 589                                  Diners, Restaurants
# 590                                   Coffee & Tea, Food
# 591               Fashion, Children's Clothing, Shopping
# 592    Bars, Cocktail Bars, Coffee & Tea, Food, Resta...
# 593    Italian, American (Traditional), Pizza, Restau...
# 594     Contractors, Garage Door Services, Home Services
# 595    Nightlife, Seafood, Bars, Restaurants, America...
# 596    Pretzels, Shopping Centers, Food, Shopping, Ba...
# 597                      Restaurants, African, Caribbean
# 598    Food, Breakfast & Brunch, Restaurants, Bagels,...
# 599                              Automotive, Auto Repair
# 600    Shopping, Women's Clothing, Jewelry, Fashion, ...
# 601    Chicken Wings, Salad, Restaurants, Pizza, Ital...
# 602    Event Planning & Services, Wedding Planning, F...
# 603    Apartments, University Housing, Home Services,...
# 604    Carpenters, Refinishing Services, Flooring, Ho...
# 605    Movers, Local Services, Furniture Assembly, Ho...
# 606                                Nightlife, Bars, Pubs
# 607    Party Supplies, Event Planning & Services, Par...
# 608    Restaurants, Chicken Shop, Fast Food, Chicken ...
# 609    Apartments, Real Estate, Home Services, Proper...
# 610    Korean, American (Traditional), Sandwiches, Ch...
# 611                                         Food, Donuts
# 612                  Automotive, Auto Repair, Body Shops
# 613                                   Coffee & Tea, Food
# 614              Towing, Roadside Assistance, Automotive
# 615    Recreation Centers, Arts & Entertainment, Virt...
# 616    Bars, Nightlife, American (Traditional), Music...
# 617              Nail Salons, Hair Salons, Beauty & Spas
# 618    Delis, Convenience Stores, Restaurants, Food, ...
# 619                                 Car Wash, Automotive
# 620    Restaurants, Bakeries, Cafes, Bagels, Food, So...
# 621    Delis, Kebab, Turkish, Mediterranean, Greek, R...
# 622    Cosmetic Dentists, Health & Medical, Endodonti...
# 623    Amusement Parks, Arts & Entertainment, Kids Ac...
# 624    Breakfast & Brunch, Restaurants, American (Tra...
# 625    Restaurants, American (New), Event Planning & ...
# 626                  Florists, Shopping, Flowers & Gifts
# 627    Southern, American (New), Breakfast & Brunch, ...
# 628    American (Traditional), Pubs, Sports Bars, Nig...
# 629                 Car Wash, Automotive, Auto Detailing
# 630    Beauty & Spas, Nail Salons, Hair Salons, Hair ...
# 631    Desserts, Food, Ice Cream & Frozen Yogurt, Sha...
# 632                               Hotels & Travel, Tours
# 633                                       Local Services
# 634    American (New), Restaurants, Event Planning & ...
# 635    Preschools, Recreation Centers, Education, Gym...
# 636    Desserts, Breweries, Breakfast & Brunch, Resta...
# 637                                   Parks, Active Life
# 638    Automotive, Auto Repair, Oil Change Stations, ...
# 639                    Restaurants, Sushi Bars, Japanese
# 640    Bars, Breweries, Beer Tours, Tours, Food, Hote...
# 641               Real Estate, Home Services, Apartments
# 642    Video Game Stores, Electronics, Shopping, Book...
# 643    Metal Fabricators, Home Services, Building Sup...
# 644                       Fashion, Shopping, Shoe Stores
# 645    Awnings, Local Services, Patio Coverings, Home...
# 646    Sandwiches, Burgers, Food, Fast Food, Restaura...
# 647    Art Classes, Party & Event Planning, Education...
# 648                           Nail Salons, Beauty & Spas
# 649         Hair Salons, Massage, Beauty & Spas, Barbers
# 650                          Italian, Restaurants, Pizza
# 651    Urgent Care, Pediatricians, Doctors, Health & ...
# 652                                  Restaurants, Indian
# 653        Home Services, Flooring, Refinishing Services
# 654    Windshield Installation & Repair, Auto Glass S...
# 655    Dry Cleaning, Local Services, Laundry Services...
# 656    Tours, Travel Services, Airport Shuttles, Tran...
# 657    Signmaking, Professional Services, Shipping Ce...
# 658    Ice Cream & Frozen Yogurt, Food, Food Stands, ...
# 659      Active Life, Escape Games, Arts & Entertainment
# 660    Restaurants, Fast Food, Food, Coffee & Tea, Bu...
# 661                Guns & Ammo, Sporting Goods, Shopping
# 662                                 Mexican, Restaurants
# 663    Vegan, Gluten-Free, Restaurants, Bubble Tea, S...
# 664    Real Estate, Home Services, Real Estate Agents...
# 665         Masonry/Concrete, Contractors, Home Services
# 666    Kebab, Mediterranean, Middle Eastern, Lebanese...
# 667                       Event Planning & Services, DJs
# 668                  Home & Garden, Mattresses, Shopping
# 669    Yoga, Pilates, Fitness & Instruction, Barre Cl...
# 670                                        Grocery, Food
# 671                                 Italian, Restaurants
# 672    Hair Salons, Hair Removal, Day Spas, Skin Care...
# 673                                    Food Trucks, Food
# 674                     Local Services, Recycling Center
# 675                      Automotive, Oil Change Stations
# 676    Pasta Shops, Bars, Nightlife, Specialty Food, ...
# 677    Real Estate, Real Estate Agents, Real Estate S...
# 678    American (Traditional), Nightlife, Breakfast &...
# 679                   Restaurants, Food, Bakeries, Greek
# 680                               Beauty & Spas, Barbers
# 681     Food, Breweries, Pubs, Beer Bar, Nightlife, Bars
# 682                                Home Services, Movers
# 683    Gelato, Chocolatiers & Shops, Food, Gift Shops...
# 684    Flooring, Contractors, Windows Installation, H...
# 685    Baby Gear & Furniture, Shopping, Fashion, Chil...
# 686                      Local Services, Carpet Cleaning
# 687    Automotive, Auto Repair, Oil Change Stations, ...
# 688    Nightlife, Bars, Beer, Wine & Spirits, Pubs, I...
# 689    Burgers, Bars, Restaurants, Nightlife, America...
# 690                  Garage Door Services, Home Services
# 691                Coffee & Tea, Coffee Roasteries, Food
# 692                            Asian Fusion, Restaurants
# 693              Nail Salons, Beauty & Spas, Hair Salons
# 694    Bars, Beer Bar, American (Traditional), Nightl...
# 695       Home Services, Real Estate, Real Estate Agents
# 696                          Car Rental, Hotels & Travel
# 697    Car Dealers, Auto Parts & Supplies, Auto Repai...
# 698    Hair Removal, Eyelash Service, Beauty & Spas, ...
# 699    Home Services, Flooring, Demolition Services, ...
# 700    University Housing, Real Estate, Home Services...
# 701    Home Services, Contractors, Siding, Gutter Ser...
# 702                    Delis, Food, Grocery, Restaurants
# 703       Bars, Nightlife, Mexican, Restaurants, Seafood
# 704    Airport Shuttles, Transportation, Hotels & Tra...
# 705    Tires, Automotive, Oil Change Stations, Auto R...
# 706                                 Restaurants, Chinese
# 707                         Food, Juice Bars & Smoothies
# 708    Jewelry, Shopping, Local Services, Jewelry Repair
# 709    Restaurants, American (Traditional), Burgers, ...
# 710    Historical Tours, Hotels & Travel, Bar Crawl, ...
# 711    Nightlife, Bars, Music Venues, Dive Bars, Arts...
# 712    Beer, Wine & Spirits, Shopping, Flowers & Gift...
# 713             Home & Garden, Hardware Stores, Shopping
# 714    Hair Salons, Beauty & Spas, Nail Salons, Day S...
# 715    Home Services, Home Cleaning, Office Cleaning,...
# 716            Beauty & Spas, Hair Stylists, Hair Salons
# 717    Oil Change Stations, Automotive, Auto Glass Se...
# 718    Arts & Entertainment, Haunted Houses, Local Fl...
# 719                          Restaurants, Pizza, Italian
# 720                   Italian, Delis, Restaurants, Salad
# 721    Chinese, Specialty Food, Food, Event Planning ...
# 722                      Ice Cream & Frozen Yogurt, Food
# 723    Home Services, Painters, Contractors, Pressure...
# 724    Parks, Skate Parks, Tubing, Arts & Entertainme...
# 725                                Shopping, Guns & Ammo
# 726    Breakfast & Brunch, Coffee & Tea, Food, Ice Cr...
# 727                                    Restaurants, Thai
# 728                           Food, Donuts, Coffee & Tea
# 729    Tutoring Centers, Specialty Schools, Test Prep...
# 730    Shopping, Drugstores, Food, Convenience Stores...
# 731    Italian, Bars, Restaurants, Nightlife, Wine Ba...
# 732    Local Services, Laundry Services, Dry Cleaning...
# 733            Fast Food, Sandwiches, Delis, Restaurants
# 734                       Shoe Stores, Shopping, Fashion
# 735                                   Coffee & Tea, Food
# 736    Festivals, Art Galleries, Local Flavor, Commun...
# 737    Fitness & Instruction, Yoga, Dance Studios, Ac...
# 738    Golf, Venues & Event Spaces, Event Planning & ...
# 739    Local Services, Shopping, Sporting Goods, Bike...
# 740               Apartments, Home Services, Real Estate
# 741                           Bars, Nightlife, Dive Bars
# 742    Breakfast & Brunch, Restaurants, Food, Cafes, ...
# 743    Skin Care, Health & Medical, Massage Therapy, ...
# 744    Limos, Party Bus Rentals, Transportation, Hote...
# 745    Day Camps, Fitness & Instruction, Summer Camps...
# 746                           Nail Salons, Beauty & Spas
# 747    Jewelry Repair, Local Services, Shopping, Appr...
# 748                       Restaurants, Vegan, Vegetarian
# 749           Doctors, Health & Medical, Family Practice
# 750    Wigs, Arts & Crafts, Sewing & Alterations, Sho...
# 751    Home & Garden, Art Supplies, Arts & Crafts, Sh...
# 752                      Lice Services, Health & Medical
# 753    General Dentistry, Endodontists, Urgent Care, ...
# 754       Heating & Air Conditioning/HVAC, Home Services
# 755                      Ice Cream & Frozen Yogurt, Food
# 756    Commercial Real Estate, Shopping, Apartments, ...
# 757    Shopping, Optometrists, Eyewear & Opticians, H...
# 758                                  Restaurants, Indian
# 759    Japanese, Sushi Bars, Food, Restaurants, Asian...
# 760                               Beauty & Spas, Tanning
# 761                              Home Services, Plumbing
# 762                          American (New), Restaurants
# 763    Professional Services, Men's Hair Salons, Loca...
# 764                            Restaurants, Pizza, Salad
# 765                                    Golf, Active Life
# 766    Food, Gas Stations, Service Stations, Convenie...
# 767    Chiropractors, Physical Therapy, Massage Thera...
# 768                      Restaurants, Fast Food, Burgers
# 769                 Shopping, Jewelry, Watches, Antiques
# 770    Sandwiches, Breakfast & Brunch, Food Stands, I...
# 771    Restaurants, Wine Bars, Italian, Food, Sandwic...
# 772    Beauty & Spas, Estheticians, Makeup Artists, H...
# 773    Event Planning & Services, Party & Event Plann...
# 774            Beauty & Spas, Hair Salons, Hair Stylists
# 775                                  Hiking, Active Life
# 776     Waxing, Beauty & Spas, Nail Salons, Hair Removal
# 777    Restaurants, Coffee & Tea, Fast Food, Burgers,...
# 778                                 Restaurants, Mexican
# 779                      Breakfast & Brunch, Restaurants
# 780    Shaved Ice, Food Stands, Restaurants, Street V...
# 781       Indian, Restaurants, Pakistani, American (New)
# 782                 Automotive, Car Wash, Auto Detailing
# 783    Soup, Salad, American (Traditional), Vegetaria...
# 784                        Restaurants, Pizza, Fast Food
# 785    Automotive, Wheel & Rim Repair, Tires, Auto Re...
# 786         Pets, Pet Stores, Pet Services, Pet Groomers
# 787    Car Dealers, Auto Repair, Local Flavor, Automo...
# 788         Health & Medical, Hospitals, Medical Centers
# 789                  Shopping, Home & Garden, Appliances
# 790    Criminal Defense Law, Professional Services, L...
# 791     Shopping, Bookstores, Books, Mags, Music & Video
# 792                           Radio Stations, Mass Media
# 793    Hotels & Travel, Airport Shuttles, Transportation
# 794    Local Services, Preschools, Education, Element...
# 795    Event Planning & Services, Hotels & Travel, Ve...
# 796        Arts & Entertainment, Performing Arts, Cinema
# 797    Wigs, Adult Entertainment, Fashion, Adult, Art...
# 798    Restaurants, Nightlife, Dance Clubs, Falafel, ...
# 799    Automotive, Wheel & Rim Repair, Body Shops, Oi...
# 800    Tacos, Live/Raw Food, Mexican, Seafood, Burger...
# 801    Event Planning & Services, Hotels, Hotels & Tr...
# 802     Beauty & Spas, Nail Salons, Waxing, Hair Removal
# 803                                   Food, Coffee & Tea
# 804    Massage, Health & Medical, Beauty & Spas, Medi...
# 805    Travel Services, Financial Services, Insurance...
# 806           Makeup Artists, Hair Salons, Beauty & Spas
# 807    Swimming Lessons/Schools, Active Life, Educati...
# 808    Car Dealers, Auto Parts & Supplies, Tires, Aut...
# 809                       Jet Skis, Active Life, Boating
# 810    Gift Shops, Flowers & Gifts, Food, Florists, C...
# 811    Pizza, Food, Food Delivery Services, Salad, Re...
# 812    Day Spas, Cosmetics & Beauty Supply, Beauty & ...
# 813    Fitness & Instruction, Swimming Pools, Active ...
# 814                Restaurants, Pretzels, Food, Bakeries
# 815    Automotive, Used Car Dealers, Auto Repair, Car...
# 816    Hotels, Hotels & Travel, Event Planning & Serv...
# 817    Shopping, Food, Health & Medical, Pharmacy, Co...
# 818                                          Active Life
# 819    Boat Charters, Active Life, Boat Tours, Boatin...
# 820    Barbers, Men's Hair Salons, Hair Salons, Beaut...
# 821    Diners, Restaurants, Sandwiches, Breakfast & B...
# 822                   Salad, Pizza, Restaurants, Italian
# 823    Barbeque, Restaurants, Event Planning & Servic...
# 824                       Home Services, Home Inspectors
# 825    Real Estate Agents, Home Services, Local Servi...
# 826        Arts & Entertainment, Music Venues, Nightlife
# 827    Automotive, Auto Repair, Oil Change Stations, ...
# 828                             Steakhouses, Restaurants
# 829    Flowers & Gifts, Chocolatiers & Shops, Florist...
# 830                                   Pizza, Restaurants
# 831                                   Delis, Restaurants
# 832         Art Classes, Education, Arts & Entertainment
# 833    Car Dealers, Auto Repair, Automotive, Used Car...
# 834    Automotive, Auto Repair, Oil Change Stations, ...
# 835    Food, Coffee & Tea, Gas Stations, Restaurants,...
# 836                                Restaurants, Barbeque
# 837    Hair Salons, Massage, Hair Removal, Waxing, Be...
# 838                Restaurants, Sandwiches, Cheesesteaks
# 839           Shopping, Building Supplies, Home Services
# 840          Barbeque, Asian Fusion, Restaurants, Korean
# 841                      Breakfast & Brunch, Restaurants
# 842                         Self Storage, Local Services
# 843    Health & Medical, Professional Services, Life ...
# 844    Coffee & Tea, Food, Restaurants, Internet Cafe...
# 845                                 Chinese, Restaurants
# 846                               Beauty & Spas, Barbers
# 847                                   Parks, Active Life
# 848    Towing, Automotive, Auto Parts & Supplies, Aut...
# 849    Car Dealers, Auto Repair, Automotive, Used Car...
# 850    Restaurants, Breakfast & Brunch, Steakhouses, ...
# 851    Health & Medical, Cosmetic Dentists, Dentists,...
# 852    Jewelry, Shopping, Watch Repair, Bridal, Local...
# 853    Landscaping, Professional Services, Home Services
# 854                             Active Life, Playgrounds
# 855                           Food, Beer, Wine & Spirits
# 856    Flowers & Gifts, Specialty Food, Shopping, Foo...
# 857    Restaurants, Bars, Wine Bars, American (Tradit...
# 858    Hotels & Travel, Hotels, Event Planning & Serv...
# 859    Fashion, Men's Clothing, Shopping, Shoe Stores...
# 860      Food, Restaurants, French, Beer, Wine & Spirits
# 861    Yoga, Gyms, Sports Clubs, Active Life, Trainer...
# 862    Fertility, Obstetricians & Gynecologists, Doct...
# 863                Restaurants, Delis, Salad, Sandwiches
# 864    Shaved Ice, Juice Bars & Smoothies, Desserts, ...
# 865    Food, Nightlife, Restaurants, Irish Pub, Bars,...
# 866    Steakhouses, Restaurants, Nightlife, Seafood, ...
# 867                                        Grocery, Food
# 868    Farmers Market, Specialty Food, Food, Fruits &...
# 869    Flowers & Gifts, Building Supplies, Gift Shops...
# 870    Event Planning & Services, Cupcakes, Desserts,...
# 871    Mattresses, Furniture Stores, Shopping, Applia...
# 872    Hair Stylists, Beauty & Spas, Hair Extensions,...
# 873              Restaurants, Donuts, Coffee & Tea, Food
# 874                           Nail Salons, Beauty & Spas
# 875                                 Chinese, Restaurants
# 876    Accessories, Women's Clothing, Fashion, Shoppi...
# 877                 Shopping, Department Stores, Fashion
# 878    Real Estate Agents, Home Services, Real Estate...
# 879                              Plumbing, Home Services
# 880    Beauty & Spas, Hair Salons, Cosmetics & Beauty...
# 881         Restaurants, Cajun/Creole, Seafood, Southern
# 882    Gas Stations, Auto Repair, Automotive, Oil Cha...
# 883    Shopping, Beauty & Spas, Cosmetics & Beauty Su...
# 884    Men's Hair Salons, Hair Salons, Barbers, Beaut...
# 885    Auto Repair, Automotive, Auto Detailing, Motor...
# 886                              Auto Repair, Automotive
# 887                               Barbers, Beauty & Spas
# 888                              Day Spas, Beauty & Spas
# 889    Tapas Bars, Music Venues, Restaurants, Arts & ...
# 890                      Restaurants, Fast Food, Mexican
# 891    Women's Clothing, Shopping, Outlet Stores, Men...
# 892                                Barbeque, Restaurants
# 893    Coffee & Tea, Bakeries, Desserts, Food, Ice Cr...
# 894    Event Photography, Photographers, Session Phot...
# 895    Home & Garden, Shopping, Furniture Stores, Ant...
# 896    Pawn Shops, Shopping, Antiques, Jewelry, Gold ...
# 897    Fashion, Outdoor Furniture Stores, Building Su...
# 898                        Buffets, Restaurants, Chinese
# 899                    Auto Parts & Supplies, Automotive
# 900    Hair Salons, Makeup Artists, Beauty & Spas, Br...
# 901               Chinese, Restaurants, Seafood, Noodles
# 902    Pizza, Seafood, Restaurants, Mexican, Italian,...
# 903         Laundromat, Local Services, Laundry Services
# 904    Apartments, Shopping Centers, Property Managem...
# 905           Electronics, Jewelry, Shopping, Pawn Shops
# 906    Restaurants, American (Traditional), Bars, Nig...
# 907                  Animal Shelters, Pet Adoption, Pets
# 908    Vegan, Pakistani, Indian, Vegetarian, Restaurants
# 909    American (Traditional), Restaurants, Breakfast...
# 910                           Beer, Wine & Spirits, Food
# 911    Gutter Services, Landscape Architects, Home Se...
# 912                               Restaurants, Caribbean
# 913                                   Parks, Active Life
# 914                                  Veterinarians, Pets
# 915          Burgers, Desserts, Restaurants, Food, Salad
# 916             Restaurants, Mexican, Fast Food, Tex-Mex
# 917    Event Planning & Services, Bed & Breakfast, Ho...
# 918                  Tobacco Shops, Vape Shops, Shopping
# 919    Home Decor, Paint Stores, Home & Garden, Shopping
# 920    Breweries, American (New), Restaurants, Burger...
# 921    Restaurants, Gluten-Free, Pizza, Vegan, Fast Food
# 922         Trinidadian, Caribbean, Restaurants, Seafood
# 923                               Barbers, Beauty & Spas
# 924    Sandwiches, Restaurants, Barbeque, Food Trucks...
# 925                   Food, Candy Stores, Specialty Food
# 926    Smog Check Stations, Wheel & Rim Repair, Auto ...
# 927    Dog Walkers, Pet Services, Health & Medical, R...
# 928                                Japanese, Restaurants
# 929    Food, Grocery, Beer, Wine & Spirits, Discount ...
# 930              Pizza, Italian, Sandwiches, Restaurants
# 931    Hotels, Hotels & Travel, Event Planning & Serv...
# 932    Teeth Whitening, General Dentistry, Health & M...
# 933    Shopping, Shoe Stores, Fashion, Accessories, W...
# 934    Comfort Food, Restaurants, Italian, Asian Fusi...
# 935               Shopping, Local Flavor, Souvenir Shops
# 936                                    Active Life, Golf
# 937                              Auto Repair, Automotive
# 938    Automotive, Restaurants, Sandwiches, Bars, Nig...
# 939              Donuts, Food, Coffee & Tea, Restaurants
# 940    Delis, Gas Stations, Food, Convenience Stores,...
# 941    Local Services, Thrift Stores, Donation Center...
# 942                 Ranches, Arts & Entertainment, Farms
# 943    Fitness & Instruction, Health & Medical, Weigh...
# 944    Health & Medical, Pediatric Dentists, Dentists...
# 945    Health & Medical, General Dentistry, Cosmetic ...
# 946    Beer, Wine & Spirits, Pubs, Arts & Entertainme...
# 947    Auto Detailing, Automotive, Auto Repair, Auto ...
# 948                      Burgers, Restaurants, Fast Food
# 949            Fast Food, Delis, Restaurants, Sandwiches
# 950    Flowers & Gifts, Specialty Food, Home Decor, S...
# 951    Sandwiches, Vegetarian, Pizza, Food, Coffee & ...
# 952    Couriers & Delivery Services, Professional Ser...
# 953    Beer, Wine & Spirits, Organic Stores, Grocery,...
# 954    Event Planning & Services, Caterers, Fast Food...
# 955                          Pizza, Restaurants, Italian
# 956           Coffee & Tea, Juice Bars & Smoothies, Food
# 957    Bars, Breakfast & Brunch, Restaurants, Barbequ...
# 958                                 Restaurants, Chinese
# 959      Property Management, Real Estate, Home Services
# 960               Real Estate, Apartments, Home Services
# 961               Hotels & Travel, RV Parks, Campgrounds
# 962    Beauty & Spas, Tanning, Nail Salons, Hair Salo...
# 963                   Donuts, Food, Bagels, Coffee & Tea
# 964                   Sandwiches, Fast Food, Restaurants
# 965                          Restaurants, Food, Bakeries
# 966    Music & DVDs, Shopping, Vinyl Records, Books, ...
# 967    Movers, Home Services, Junk Removal & Hauling,...
# 968    Nightlife, American (New), Music Venues, Resta...
# 969                           Beauty & Spas, Nail Salons
# 970            Car Dealers, Used Car Dealers, Automotive
# 971    Restaurants, Italian, Soup, Bars, Salad, Night...
# 972                           Active Life, Skating Rinks
# 973    Auto Repair, Automotive, Oil Change Stations, ...
# 974    Rehabilitation Center, Health & Medical, Physi...
# 975    Flowers & Gifts, Shopping, Specialty Food, Bee...
# 976    Japanese, Asian Fusion, Wine Bars, Bars, Resta...
# 977    Hotels, Event Planning & Services, Hotels & Tr...
# 978                                   Coffee & Tea, Food
# 979    Furniture Stores, Home Services, Building Supp...
# 980     Waxing, Hair Removal, Beauty & Spas, Hair Salons
# 981                Chicken Wings, Fast Food, Restaurants
# 982                              Home Services, Shutters
# 983                          Local Services, Shoe Repair
# 984    Bridal, Jewelry, Fashion, Sewing & Alterations...
# 985                                 Automotive, Car Wash
# 986    Hair Salons, Nail Salons, Beauty & Spas, Skin ...
# 987                                 Italian, Restaurants
# 988    Auto Repair, Oil Change Stations, Automotive, ...
# 989                          Restaurants, Pizza, Italian
# 990    Auto Repair, Car Dealers, Oil Change Stations,...
# 991    Beauty & Spas, Hair Extensions, Makeup Artists...
# 992    Home Services, Home & Garden, Shopping, Garden...
# 993    Auto Repair, Body Shops, Transmission Repair, ...
# 994                Sporting Goods, Shopping, Guns & Ammo
# 995                      Fast Food, Burgers, Restaurants
# 996            Banks & Credit Unions, Financial Services
# 997     Public Services & Government, Police Departments
# 998                 Fashion, Shopping, Department Stores
# 999    Waxing, Beauty & Spas, Eyelash Service, Used, ...
# Name: categories, dtype: object
# Showing only the first 1000

# %%
def values_type(dataframe, column): 
  types = set()
  for value in dataframe[column].to_numpy():
    types.add(type(value))
  return types
# Out:
# {<class 'NoneType'>, <class 'pyspark.sql.types.Row'>}

# %%
values_type(k_business, 'hours')

# %%
type(k_business.hours[50])
# Out:
# pyspark.sql.types.Row

# %%
def extract_keys(dataframe, column:str):
  schedule_keys = set()
  for value in dataframe[column].to_numpy():
    try:
      schedule_dict = value.asDict()
      keys = schedule_dict.keys()
      for x in keys:
        schedule_keys.add(x)
    except AttributeError:
      pass
  return schedule_keys
# Out:
# {'Friday', 'Tuesday', 'Wednesday', 'Sunday', 'Thursday', 'Saturday', 'Monday'}

# %%
extract_keys(k_business, 'hours')

# %%
def get_schedule(value, day:str, time:str):
  try:
    hours_dict = value.asDict()
    hours = hours_dict[day].split('-')
    if time == 'open':
      return hours[0]
    elif time == 'close':
      return hours[1]
  except AttributeError:
    return 'NO DATA'

# %%
k_business['monday_open'] = k_business.hours.apply(get_schedule, args=('Monday', 'open'))
# Out:
# /content/spark-3.1.3-bin-hadoop2.7/python/pyspark/sql/pandas/functions.py:392: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   "in the future releases. See SPARK-28264 for more details.", UserWarning)

# %%
k_business.columns
# Out:
# Index(['address', 'attributes', 'business_id', 'categories', 'city', 'hours',
#        'is_open', 'latitude', 'longitude', 'name', 'postal_code',
#        'review_count', 'stars', 'state', 'monday_open'],
#       dtype='object')
